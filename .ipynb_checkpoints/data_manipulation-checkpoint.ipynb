# %%
import geopandas
from geopy.geocoders import Nominatim
import pandas as pd

# %%
df = pd.read_csv("./trento/2020.csv")
addresses = df['address'].to_list()
for i in range(0,len(addresses)) : 
    addresses[i] = addresses[i][2:-2].replace('\', \'', ',')
    addresses[i] = addresses[i].replace('\', \"', ',')    
    addresses[i] = addresses[i].replace('Centro storico','Trento')

# %%
addresses
# Out:
# ['Gardolo,via Giambattista Unterveger',
#  'Gardolo,Via Alto Adige',
#  '',
#  'Trento,Piazza Dante',
#  'Oltrefersina,Via Aosta',
#  "Oltrefersina,Largo Medaglie d'oro",
#  'Cavedago',
#  'Trento,Piazza del Duomo',
#  '',
#  'Riva del Garda,SS240, 17',
#  'Gardolo,Via Alto Adige',
#  'Vattaro',
#  'Trento,Via Carlo Rosmini',
#  'Povo,Via Sommarive',
#  'Canal San Bovo,Monte Vederna',
#  'Trento,Via Andrea Pozzo',
#  'Oltrefersina,Viale Verona',
#  'Rovereto,Via Pasubio',
#  'Oltrefersina,Viale Verona',
#  "Oltrefersina,Largo Medaglie d'oro",
#  'Gardolo,Via Alto Adige',
#  'località Mattarello',
#  'Vallarsa,Pasubio',
#  'Ledro,Tiarno di Sotto',
#  '',
#  '',
#  '',
#  '',
#  'Denno',
#  'Pergine Valsugana',
#  'Mori',
#  'Trento,Piazza Dante',
#  "Oltrefersina,Largo Medaglie d'oro",
#  'Trento,Corso Bettini, 43',
#  'Trento,Via Oriola',
#  'Moena,Strada Statale 346 del Passo di San Pellegrino',
#  'Cles,Peller',
#  'Trento,Piazza Dante',
#  'Argentario,Strada Statale 47 della Valsugana',
#  'Trento,Via Endrici Monsignor Celestino',
#  'Trento,Via Andrea Pozzo',
#  '',
#  'Trento,Piazza Dante',
#  'Trento,Piazza Dante',
#  'Luserna',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Rovereto',
#  '',
#  'Villazzano,Via San Rocco',
#  'Cles,Viale Alcide De Gasperi, 31',
#  'Riva del Garda,Via Brescia',
#  'Canazei,Punta Penia',
#  'Trento,Piazza Cesare Battisti',
#  'Gardolo,Via Alto Adige',
#  'Trento,Vicolo della Sat',
#  'Cles',
#  'Trento,Piazza del Duomo',
#  'Trento,Piazza Dante',
#  "Oltrefersina,Largo Medaglie d'oro",
#  'Gardolo,Via Alto Adige',
#  'Trento,Via Giannantonio Manci',
#  'Oltrefersina,Viale Verona',
#  'Trento,Via Andrea Pozzo',
#  'Oltrefersina,Viale Verona',
#  'Trento,Via Oriola',
#  'Ledro,rifugio Pernici',
#  "Oltrefersina,Largo Medaglie d'oro",
#  'Piazza Dolomiti',
#  "Oltrefersina,Largo Medaglie d'oro",
#  'Calceranica al Lago',
#  'Lavis',
#  'Trento,Via Andrea Pozzo',
#  'Trento,Via Giannantonio Manci',
#  'Predazzo,Paneveggio',
#  'Trento,Via Giannantonio Manci',
#  'Rovereto,A22',
#  'Fai della Paganella',
#  'Trento,Via Oriola',
#  'Trento,Piazza Dante',
#  'Trento,Via Lavisotto',
#  'Trento,Piazza Dante',
#  'Ledro',
#  'San Giuseppe,Via dei Muredei',
#  'Gardolo,Via Aeroporto',
#  'San Giuseppe,Via Giuseppe Giusti',
#  'Trento,Piazza del Duomo',
#  'Trento,Via Torre Vanga',
#  'Gardolo,Via Bolzano',
#  'Trento,Piazza del Duomo',
#  'Trento,Piazza del Duomo',
#  'Povo,Via Sommarive',
#  'Revò',
#  "Oltrefersina,Via Sant'Antonio",
#  '',
#  'Trento,Piazza del Duomo',
#  '',
#  'Croviana',
#  '',
#  '',
#  '',
#  'Bresimo',
#  '',
#  'Ossana',
#  'Pozza di Fassa',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Gardolo,Via Alto Adige',
#  "Oltrefersina,Largo Medaglie d'oro",
#  'Rovereto,A22',
#  'Fierozzo',
#  'Gardolo,Via Bolzano',
#  'Trento,Via Giovanni Zanella',
#  'Trento,Via Giannantonio Manci',
#  'San Giuseppe,Via Vittorio Veneto',
#  'Trento,Via Francesco Petrarca',
#  "Oltrefersina,Largo Medaglie d'oro",
#  'Giustino',
#  'Caldonazzo',
#  'Trento,Via Clementino Vannetti',
#  'Via Innsbruck',
#  "Oltrefersina,Largo Medaglie d'oro",
#  'Gardolo,Via Alto Adige',
#  'Trento,Vicolo della Sat',
#  'San Giuseppe,Via Cristoforo Madruzzo',
#  'Oltrefersina,Viale Nepomuceno Bolognini',
#  'Calavino,Strada Provinciale 84',
#  '',
#  "Oltrefersina,Largo Medaglie d'oro",
#  'Pozza di Fassa,Strada Statale 48',
#  'San Giuseppe,Via Milano',
#  'Trento,Piazza del Duomo',
#  'Carisolo,Cima Sassara',
#  'Riva del Garda',
#  'Trento,Via Clementino Vannetti, 6',
#  'Gardolo,Via Alto Adige',
#  'Trento,Piazza Dante',
#  'Trento,Via Andrea Pozzo',
#  'Trento,Via Dogana',
#  'Nago-Torbole,Strada Statale 240',
#  'Gardolo,Via Alto Adige',
#  '',
#  '',
#  '',
#  'Drena',
#  '',
#  '',
#  'Comano Terme',
#  '',
#  'Luserna',
#  'Trento,A22',
#  'Folgaria',
#  '',
#  'Fai della Paganella',
#  '',
#  '',
#  "Oltrefersina,Largo Medaglie d'oro",
#  'Trento,Piazza del Duomo',
#  'San Giuseppe,Corso del Lavoro e della Scienza, 3',
#  'Rovereto,A22',
#  'Cagnò,Strada Provinciale 139',
#  'Pinzolo,Viale Dolomiti di Brenta',
#  'Trento,Via Vittorio Alfieri',
#  'Gardolo,Via Bolzano',
#  'Oltrefersina,Viale Verona',
#  'Caldonazzo',
#  'San Giuseppe,Via Carlo Antonio Pilati',
#  'Trento,Via Clementino Vannetti',
#  'Pinzolo',
#  'San Giuseppe,Via Francesco Barbacovi',
#  'Gardolo,Via Bolzano',
#  'Mori,Passo San Giovanni',
#  'Trento,Via Giuseppe Verdi',
#  'Grigno,Selva',
#  'Rovereto,Lenzima',
#  'Oltrefersina,Viale Verona',
#  '',
#  'Ronzone',
#  'Storo',
#  "Trento,Piazza Podesta'",
#  'Trento,Piazza Dante',
#  'Trento,Piazza Dante',
#  'Novaledo',
#  'Gardolo,Via Alto Adige',
#  'Riva del Garda,Piazza della Chiesa, 12',
#  'Trento,Piazza Dante',
#  'Trento,Via Brescia',
#  "Oltrefersina,Largo Medaglie d'oro",
#  'Trento,Piazza Cesare Battisti',
#  'Trento,Via Giuseppe Gilli',
#  'Nogaredo,A22',
#  'Gardolo,Via Alto Adige',
#  'Trento,Piazza Dante']

# %% [markdown]
# replacing a list of items from address

# %%
df_complete = df
df_complete["address"] = addresses

# %%
df_complete
# Out:
#      Unnamed: 0                                              title  \
# 0             0             Recuperato il corpo di Daniele Catorci
# 1             1  Cade nel fiume: ripescato vivo un chilometro e...
# 2             2  La Provincia: "L'orso del video sarà catturato...
# 3             3  Sagra della braciola d'orso con il patrocinio ...
# 4             4  Dramma sul Gran Paradiso: individuato lo zaino...
# ..          ...                                                ...
# 195         195  Il Teatro Sociale riparte aprendo le porte del...
# 196         196  Nidi e materne possono riaprire, una famiglia ...
# 197         197      Tir avvolto dalle fiamme all'area di servizio
# 198         198  Scivola dalle rocce nel torrente: capo del Soc...
# 199         199  Nessun decesso e 5 contagi. Asili: solo una fa...
#
#                                               subtitle  \
# 0    Il giovane alpinista, dottorando all'Universit...
# 1    Diversi corpi di Vigili del Fuoco hanno presid...
# 2    La nota della Pat sul video che sta spopolando...
# 3    La notizia ha gettato benzina sul fuoco, ma l'...
# 4    Nel crepaccio dove il giovane alpinista è cadu...
# ..                                                 ...
# 195  Stagione estiva inedita al via dal 15 giugno c...
# 196  Adesioni al 36% per la riapertura dei servizi ...
# 197  Paura in A22, il rimorchio di un tir è stato d...
# 198  E' scivolato mentre stava smontando del materi...
# 199  Ecco i dati aggiornati sulla situazione in Tre...
#
#                                                   link             timestamp  \
# 0    http://www.trentotoday.it/cronaca/daniele-cato...  29 giugno 2020 19:48
# 1    http://www.trentotoday.it/cronaca/cade-fiume-b...  29 giugno 2020 17:47
# 2    http://www.trentotoday.it/green/orso-video-cat...  29 giugno 2020 17:28
# 3    http://www.trentotoday.it/attualita/sagra-brac...  29 giugno 2020 16:04
# 4    http://www.trentotoday.it/cronaca/morto-gran-p...  29 giugno 2020 15:12
# ..                                                 ...                   ...
# 195  http://www.trentotoday.it/eventi/cultura/teatr...  07 giugno 2020 15:44
# 196  http://www.trentotoday.it/cronaca/asili-nido-m...  07 giugno 2020 15:33
# 197  http://www.trentotoday.it/cronaca/incendio-tir...  07 giugno 2020 12:38
# 198  http://www.trentotoday.it/cronaca/lukas-forer-...  07 giugno 2020 11:59
# 199  http://www.trentotoday.it/cronaca/morti-contag...  06 giugno 2020 18:16
#
#                                                   text  \
# 0    E' stato recuperato nel pomeriggio di lunedì 2...
# 1    E' stato ripescato vivo dalle acque dell'Isarc...
# 2    Un orso segue pacificamente un'escursionista n...
# 3    Sagra della braciola di orso, con il patrocini...
# 4    Sono ancora in corso le operazioni a 3.400 met...
# ..                                                 ...
# 195  Un palco all'aperto, nella piazza dietro al te...
# 196  Asili nido e scuole materne riaprono in Trenti...
# 197  Momenti di paura all'area di servizio di Nogar...
# 198  Doveva essere un'esercitazione, ma è finita in...
# 199  Un altro giorno senza vittime di coronavirus i...
#
#                                               keywords  \
# 0             ['incidenti montagna', 'morti montagna']
# 1                             ['annegamenti', 'fiumi']
# 2                            ['orsi', 'orso', 'video']
# 3                                ['fake news', 'orsi']
# 4    ['Daniele Catorci', 'Argomenti:', 'morti', 'mo...
# ..                                                 ...
# 195  ['Andrea Castelli', 'Argomenti:', 'teatro', 't...
# 196             ['asili', 'asili nido', 'coronavirus']
# 197                    ['a22', 'incendi', 'trasporti']
# 198                   ['alpinismo', 'soccorso alpino']
# 199                     ['asili', 'morti coronavirus']
#
#                                  address
# 0    Gardolo,via Giambattista Unterveger
# 1                 Gardolo,Via Alto Adige
# 2
# 3                    Trento,Piazza Dante
# 4                 Oltrefersina,Via Aosta
# ..                                   ...
# 195        Trento,Piazza Cesare Battisti
# 196            Trento,Via Giuseppe Gilli
# 197                         Nogaredo,A22
# 198               Gardolo,Via Alto Adige
# 199                  Trento,Piazza Dante
#
# [200 rows x 8 columns]

# %%
from geopy.extra.rate_limiter import RateLimiter
# 1 - conveneint function to delay between geocoding calls
geocode = RateLimiter(locator.geocode, min_delay_seconds=1)

# %%
# 2- - create location column
df_complete['location'] = df_complete['address'].apply(geocode)

# %%
# 3 - create longitude, laatitude and altitude from location column (returns tuple)
df_complete['point'] = df_complete['location'].apply(lambda loc: tuple(loc.point) if loc else (0.0,0.0,0.0))

# %%
# 4 - split point column into latitude, longitude and altitude columns
df_complete[['latitude', 'longitude', 'altitude']] = pd.DataFrame(df_complete['point'].tolist(), index=df_complete.index)

# %%
df_complete
# Out:
#      Unnamed: 0                                              title  \
# 0             0             Recuperato il corpo di Daniele Catorci
# 1             1  Cade nel fiume: ripescato vivo un chilometro e...
# 2             2  La Provincia: "L'orso del video sarà catturato...
# 3             3  Sagra della braciola d'orso con il patrocinio ...
# 4             4  Dramma sul Gran Paradiso: individuato lo zaino...
# ..          ...                                                ...
# 195         195  Il Teatro Sociale riparte aprendo le porte del...
# 196         196  Nidi e materne possono riaprire, una famiglia ...
# 197         197      Tir avvolto dalle fiamme all'area di servizio
# 198         198  Scivola dalle rocce nel torrente: capo del Soc...
# 199         199  Nessun decesso e 5 contagi. Asili: solo una fa...
#
#                                               subtitle  \
# 0    Il giovane alpinista, dottorando all'Universit...
# 1    Diversi corpi di Vigili del Fuoco hanno presid...
# 2    La nota della Pat sul video che sta spopolando...
# 3    La notizia ha gettato benzina sul fuoco, ma l'...
# 4    Nel crepaccio dove il giovane alpinista è cadu...
# ..                                                 ...
# 195  Stagione estiva inedita al via dal 15 giugno c...
# 196  Adesioni al 36% per la riapertura dei servizi ...
# 197  Paura in A22, il rimorchio di un tir è stato d...
# 198  E' scivolato mentre stava smontando del materi...
# 199  Ecco i dati aggiornati sulla situazione in Tre...
#
#                                                   link             timestamp  \
# 0    http://www.trentotoday.it/cronaca/daniele-cato...  29 giugno 2020 19:48
# 1    http://www.trentotoday.it/cronaca/cade-fiume-b...  29 giugno 2020 17:47
# 2    http://www.trentotoday.it/green/orso-video-cat...  29 giugno 2020 17:28
# 3    http://www.trentotoday.it/attualita/sagra-brac...  29 giugno 2020 16:04
# 4    http://www.trentotoday.it/cronaca/morto-gran-p...  29 giugno 2020 15:12
# ..                                                 ...                   ...
# 195  http://www.trentotoday.it/eventi/cultura/teatr...  07 giugno 2020 15:44
# 196  http://www.trentotoday.it/cronaca/asili-nido-m...  07 giugno 2020 15:33
# 197  http://www.trentotoday.it/cronaca/incendio-tir...  07 giugno 2020 12:38
# 198  http://www.trentotoday.it/cronaca/lukas-forer-...  07 giugno 2020 11:59
# 199  http://www.trentotoday.it/cronaca/morti-contag...  06 giugno 2020 18:16
#
#                                                   text  \
# 0    E' stato recuperato nel pomeriggio di lunedì 2...
# 1    E' stato ripescato vivo dalle acque dell'Isarc...
# 2    Un orso segue pacificamente un'escursionista n...
# 3    Sagra della braciola di orso, con il patrocini...
# 4    Sono ancora in corso le operazioni a 3.400 met...
# ..                                                 ...
# 195  Un palco all'aperto, nella piazza dietro al te...
# 196  Asili nido e scuole materne riaprono in Trenti...
# 197  Momenti di paura all'area di servizio di Nogar...
# 198  Doveva essere un'esercitazione, ma è finita in...
# 199  Un altro giorno senza vittime di coronavirus i...
#
#                                               keywords  \
# 0             ['incidenti montagna', 'morti montagna']
# 1                             ['annegamenti', 'fiumi']
# 2                            ['orsi', 'orso', 'video']
# 3                                ['fake news', 'orsi']
# 4    ['Daniele Catorci', 'Argomenti:', 'morti', 'mo...
# ..                                                 ...
# 195  ['Andrea Castelli', 'Argomenti:', 'teatro', 't...
# 196             ['asili', 'asili nido', 'coronavirus']
# 197                    ['a22', 'incendi', 'trasporti']
# 198                   ['alpinismo', 'soccorso alpino']
# 199                     ['asili', 'morti coronavirus']
#
#                                  address  \
# 0    Gardolo,via Giambattista Unterveger
# 1                 Gardolo,Via Alto Adige
# 2
# 3                    Trento,Piazza Dante
# 4                 Oltrefersina,Via Aosta
# ..                                   ...
# 195        Trento,Piazza Cesare Battisti
# 196            Trento,Via Giuseppe Gilli
# 197                         Nogaredo,A22
# 198               Gardolo,Via Alto Adige
# 199                  Trento,Piazza Dante
#
#                                               location  \
# 0                                                 None
# 1    (Via Alto Adige, Spini di Gardolo, Trento, Ter...
# 2                                                 None
# 3    (Trento, Piazza Dante, Centro storico Trento, ...
# 4                                                 None
# ..                                                 ...
# 195  (Piazza Cesare Battisti, Centro storico Trento...
# 196  (Via Giuseppe Gilli, Piazzina, Nord Center, Tr...
# 197  (Nogaredo, Comunità della Vallagarina, Provinc...
# 198  (Via Alto Adige, Spini di Gardolo, Trento, Ter...
# 199  (Trento, Piazza Dante, Centro storico Trento, ...
#
#                              point   latitude  longitude  altitude
# 0                  (0.0, 0.0, 0.0)   0.000000   0.000000       0.0
# 1    (46.1148209, 11.1064463, 0.0)  46.114821  11.106446       0.0
# 2                  (0.0, 0.0, 0.0)   0.000000   0.000000       0.0
# 3    (46.0722416, 11.1193186, 0.0)  46.072242  11.119319       0.0
# 4                  (0.0, 0.0, 0.0)   0.000000   0.000000       0.0
# ..                             ...        ...        ...       ...
# 195  (46.0694905, 11.1233818, 0.0)  46.069491  11.123382       0.0
# 196  (46.0909244, 11.1198381, 0.0)  46.090924  11.119838       0.0
# 197  (45.9120887, 11.0230464, 0.0)  45.912089  11.023046       0.0
# 198  (46.1148209, 11.1064463, 0.0)  46.114821  11.106446       0.0
# 199  (46.0722416, 11.1193186, 0.0)  46.072242  11.119319       0.0
#
# [200 rows x 13 columns]

# %%
import folium

map1 = folium.Map(
    location=[59.338315,18.089960],
    tiles='cartodbpositron',
    zoom_start=12,
)
df_complete.apply(lambda row:folium.CircleMarker(location=[row["latitude"], row["longitude"]]).add_to(map1), axis=1)
map1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# !pip install geopandas
# !pip install geopy
import geopandas
import pandas as pd
import geopy
from geopy.extra.rate_limiter import RateLimiter
import time

def timer(start,end):
  hours, rem = divmod(end-start, 3600)
  minutes, seconds = divmod(rem, 60)
  return "{:0>2}:{:0>2}:{:05.2f}".format(int(hours),int(minutes),seconds)

years = ["2020"]
#"2019","2018","2017","2016","2015","2014","2013","2012",
for year in years:
  start = time.time()
  print("Sto processando l'anno {}".format(year))
  df = pd.read_csv("/content/trento_data/{}.csv".format(year))
  addresses = df['address'].to_list()
  for i in range(0,len(addresses)) : 
      addresses[i] = addresses[i][2:-2].replace('\', \'', ',')
      addresses[i] = addresses[i].replace('\', \"', ',')    
      addresses[i] = addresses[i].replace('Centro storico','Trento')

  df["address"] = addresses
  try:
    locator = geopy.geocoders.Nominatim(user_agent="today_parser")
    # 1 - conveneint function to delay between geocoding calls
    start1 = time.time()
    geocode = RateLimiter(locator.geocode, min_delay_seconds=1)
    end1 = time.time()
    print("1 - conveneint function to delay between geocoding calls. Execution time: {}".format(timer(start1, end1)))
    # 2- - create location column
    start2 = time.time()
    df['location'] = df['address'].apply(geocode)
    end2 = time.time()
    print("2- - create location column. Execution time: {}".format(timer(start2, end2)))
    # 3 - create longitude, laatitude and altitude from location column (returns tuple)
    start3 = time.time()
    df['point'] = df['location'].apply(lambda loc: tuple(loc.point) if loc else (0.0,0.0,0.0))
    end3 = time.time()
    print("3 - create longitude, laatitude and altitude from location column (returns tuple). Execution time: {}".format(timer(start3, end3)))
    # 4 - split point column into latitude, longitude and altitude columns
    start4 = time.time()
    df[['latitude', 'longitude', 'altitude']] = pd.DataFrame(df['point'].tolist(), index=df.index)
    end4 = time.time()
    print("4 - split point column into latitude, longitude and altitude columns. Execution time: {}".format(timer(start4, end4)))
  except ValueError:
    print("Qualcosa é andato storto!")
  finally:
    df.to_csv("/content/trento_data/trento_{}.csv".format(year),header = True)
    end = time.time()
    print("Tempo di esecuzione totale: {}".format(timer(start, end)))

# %%
# Out:
# Latitude = 46.0841846, Longitude = 11.2181555
