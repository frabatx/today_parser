# %% [markdown]
# # Analysis

# %%
import pandas as pd
import numpy as np
import datetime
import re
from shapely.geometry import Point, Polygon
from collections import Counter
import geopandas
from geopy.geocoders import Nominatim
import warnings
import json
import requests
import time
import warnings
warnings.filterwarnings('ignore')
# Out:
# /home/frabatx/.local/lib/python3.6/site-packages/geopandas/_compat.py:88: UserWarning: The Shapely GEOS version (3.8.0-CAPI-1.13.1 ) is incompatible with the GEOS version PyGEOS was compiled with (3.8.1-CAPI-1.13.3). Conversions between both will be slow.
#   shapely_geos_version, geos_capi_version_string

# %%
# il csv totalProcessed contiene address non ancora elaborati
# il csv toAnalize ha tutti i dati completi, mancano solo i quartieri

df = pd.read_csv('data/toAnalyse.csv')
df
# Out:
#                            address  day  \
# 0          Trento,Piazza del Duomo    8
# 1               Trento,Via Fersina    8
# 2      Trento,Largo Medaglie d'oro    7
# 3             Dro,Via Monte Casale    7
# 4             Dro,Via Monte Casale    7
# ...                            ...  ...
# 28676                          NaN    9
# 28677                          NaN    9
# 28678                          NaN    9
# 28679                          NaN    9
# 28680                          NaN    9
#
#                                                 keywords   latitude  \
# 0                   ['strade', 'trasporti', 'viabilità']  46.067647
# 1                      ['alpini', 'esercito', 'tamponi']  46.057797
# 2               ['bollettino', 'contagi', 'coronavirus']  46.057797
# 3      ['incidenti montagna', 'morti', 'morti in mont...  46.031499
# 4             ['ferrate', 'incidenti montagna', 'morti']  46.031499
# ...                                                  ...        ...
# 28676                                         ['lavoro']   0.000000
# 28677                                     ['tecnologie']   0.000000
# 28678                                      ['religione']   0.000000
# 28679                                      ['trasporti']   0.000000
# 28680                                        ['spaccio']   0.000000
#
#                                                     link  \
# 0      https://www.trentotoday.it/attualita/strada-bo...
# 1      https://www.trentotoday.it/attualita/esercito-...
# 2      https://www.trentotoday.it/cronaca/bollettino-...
# 3      https://www.trentotoday.it/cronaca/federica-ma...
# 4      https://www.trentotoday.it/cronaca/ragazza-mor...
# ...                                                  ...
# 28676  http://www.trentotoday.it/economia/progettone-...
# 28677  http://www.trentotoday.it/cronaca/internet-con...
# 28678  http://www.trentotoday.it/cronaca/moschea-gard...
# 28679  http://www.trentotoday.it/cronaca/piedibus-mea...
# 28680  http://www.trentotoday.it/cronaca/arresti-spac...
#
#                                            list_keywords  \
# 0                   ['Strade', 'Trasporti', 'Viabilità']
# 1                      ['Alpini', 'Esercito', 'Tamponi']
# 2               ['Bollettino', 'Contagi', 'Coronavirus']
# 3      ['Incidenti', 'Montagna', 'Morti', 'Morti', 'I...
# 4          ['Ferrate', 'Incidenti', 'Montagna', 'Morti']
# ...                                                  ...
# 28676                                         ['Lavoro']
# 28677                                     ['Tecnologie']
# 28678                                      ['Religione']
# 28679                                      ['Trasporti']
# 28680                                        ['Spaccio']
#
#                                                 location  longitude  month  \
# 0      "Piazza del Duomo, Centro storico Trento, Tren...  11.121092     11
# 1      "Via Fersina, Man Malpensada, Clarina, Trento,...  11.132759     11
# 2      "Largo Medaglie d'Oro, Man Malpensada, Bolgher...  11.132759     11
# 3      "Monte Casale, Via Ferrata Ernesto Che Guevara...  10.927659     11
# 4      "Monte Casale, Via Ferrata Ernesto Che Guevara...  10.927659     11
# ...                                                  ...        ...    ...
# 28676                                                NaN   0.000000     11
# 28677                                                NaN   0.000000     11
# 28678                                                NaN   0.000000     11
# 28679                                                NaN   0.000000     11
# 28680                                                NaN   0.000000     11
#
#                                                point  \
# 0                     ['11.1210924', '  46.0676474']
# 1      ['11.13275943562951', '  46.057797050000005']
# 2      ['11.13275943562951', '  46.057797050000005']
# 3                      ['10.9276592', '  46.031499']
# 4                      ['10.9276592', '  46.031499']
# ...                                              ...
# 28676                                     [0.0, 0.0]
# 28677                                     [0.0, 0.0]
# 28678                                     [0.0, 0.0]
# 28679                                     [0.0, 0.0]
# 28680                                     [0.0, 0.0]
#
#                                                 subtitle  \
# 0      La strada sarà chiusa durante le operazioni di...
# 1      Operazione del Ministero della Difesa in suppo...
# 2      Non accenna a diminuire il contagio: ecco i da...
# 3      Tragico incidente sulla "Che Guevara", probabi...
# 4      Drammatico incidente alla ferrata Che Guevara,...
# ...                                                  ...
# 28676  I sindacati non hanno raggiunto l'intesa con l...
# 28677  Presenti a Trento oltre cento relatori per dis...
# 28678  La comunità musulmana trentina potrà utilizzar...
# 28679  Hanno già aderito trentasei bambini, suddivisi...
# 28680  Secondo le indagini rifornivano circa 50 consu...
#
#                                                     text   timestamp  \
# 0       strada chiusa trasporto alberi natale comune ...  2020/11/08
# 1       arriva trento punto tamponi gestito dall eser...  2020/11/08
# 2       accenna appiattirsi linea contagi trentino 25...  2020/11/07
# 3       federica marcolla, medico mamma bambini, la v...  2020/11/07
# 4       mattinata drammatica monte casale ragazza 32 ...  2020/11/07
# ...                                                  ...         ...
# 28676                                                nan  2011/11/09
# 28677                                                nan  2011/11/09
# 28678   gardolo centro islamico consiglio stato infat...  2011/11/09
# 28679   grazie disponibilità sedici genitori volontar...  2011/11/09
# 28680   laccusa avere spacciato cocaina zona giudicar...  2011/11/09
#
#                                                    title  year
# 0      Arrivano gli alberi di Natale: chiusa la strad...  2020
# 1              Tamponi: anche a Trento arriva l'esercito  2020
# 2      Bollettino coronavirus: 251 nuovi casi in Tren...  2020
# 3      Precipita in ferrata: morta Federica Marcolla,...  2020
# 4      Dro, precipita dalla ferrata per 200 metri e m...  2020
# ...                                                  ...   ...
# 28676  Progettone: niente accordo sugli stipendi dei ...  2011
# 28677  Le nuove frontiere di internet: due giorni di ...  2011
# 28678  Centro islamico a Gardolo: il Consiglio di Sta...  2011
# 28679  Piedibus: il servizio gratuito arriva anche a ...  2011
# 28680  Spaccio di cocaina in Trentino: arrestate nove...  2011
#
# [28681 rows x 15 columns]

# %% [markdown]
# # Address
# Alcune degli address Nan sono stati interpretati male e hanno prodotto una location fittizia: Nanno. Vado a modificare questa cosa azzerando sia location sia point, latitude, longitude

# %% [raw]
# dfNullAddress = df[df['address'].isnull()]
# dfNullAddress['location'] = dfNullAddress['location'].apply(lambda x: '')
# dfNullAddress['point'] = dfNullAddress['point'].apply(lambda x: [0.0,0.0])
# dfNullAddress['latitude'] = dfNullAddress['latitude'].apply(lambda x: 0.00000)
# dfNullAddress['longitude'] = dfNullAddress['longitude'].apply(lambda x: 0.00000)
# df[df['address'].isnull()] = dfNullAddress
# df.to_csv('data/totalProcessed.csv', index=False)

# %% [markdown]
# Controllo gli indirizzi che non sono stati convertiti. Questi indirizzi sono quelli che hanno la colonna "address" ma non hanno "location".

# %% [raw]
# dfAddressed = df[pd.notna(df['address'])]
# dfAddressed

# %% [markdown]
# Tra i dati totali sono geolocalizzabili 22.536 elementi su un totale di 28.681. Di questi 22.536, 4695 sono da rivedere poiché la divisione geografica é riferita ai quartieri. Vediamo se riesco a ricavarne qualcosa.
# Esempio sono:
# * Oltrefersina -> Riferito al quartiere di trento e non ad una cittá  1619 rows
# * Argentario -> 72 Rows
# * Rimuovere la parola localitá
# * Bondone, 79 rows
# * San Giuseppe, 1191 rows
# * Gardolo, 203 rows.
#
# Let's change it

# %% [raw]
# dfNotGeolocated = dfAddressed[dfAddressed['location'].isnull()]
# indexNotGeolocated = dfNotGeolocated.index
# print(indexNotGeolocated)
# #dfNotGeolocated['address'].to_list()

# %% [raw]
# index_Gardolo = dfNotGeolocated[dfNotGeolocated['address'].str.contains('Gardolo')].index
# index_Oltrefersina = dfNotGeolocated[dfNotGeolocated['address'].str.contains('Oltrefersina')].index
# index_Bondone = dfNotGeolocated[dfNotGeolocated['address'].str.contains('Bondone')].index
# index_SGiuseppe = dfNotGeolocated[dfNotGeolocated['address'].str.contains('San Giuseppe')].index
# index_Argentario = dfNotGeolocated[dfNotGeolocated['address'].str.contains('Argentario')].index
# index_Localita = dfNotGeolocated[dfNotGeolocated['address'].str.contains('località|Località')].index
# print(len(index_Argentario),len(index_Bondone),len(index_Gardolo), len(index_Oltrefersina), len(index_SGiuseppe), len(index_Localita) )

# %% [raw]
# # Replace in stock di tutti i quartieri di trento e li sostituisco a 'Trento'
# df.iloc[index_Argentario,0] = df.iloc[index_Argentario,0].str.replace('Argentario', 'Trento')
# df.iloc[index_Oltrefersina,0] = df.iloc[index_Oltrefersina,0].str.replace('Oltrefersina', 'Trento')
# df.iloc[index_Bondone,0] = df.iloc[index_Bondone,0].str.replace('Bondone', 'Trento')
# df.iloc[index_SGiuseppe,0] = df.iloc[index_SGiuseppe,0].str.replace('San Giuseppe', 'Trento')
# df.iloc[index_Gardolo,0] = df.iloc[index_Gardolo,0].str.replace('Gardolo', 'Trento')

# %% [raw]
# #Elimino la parola 'Localitá'
# df.iloc[index_Localita,0] = df.iloc[index_Localita,0].str.replace('Località', '')
# df.iloc[index_Localita,0] = df.iloc[index_Localita,0].str.replace('località', '')

# %% [markdown]
# Arrivati a questo punto la pulizia degli address é completata ed é possibile rimappare i punti non geocodificati in precedenza

# %% [raw]
# df.iloc[indexNotGeolocated,0]

# %% [raw]
# # Geocoder class
# class Geocoder:
#     #base url
#     base_url = 'https://nominatim.openstreetmap.org/search'
#
#     def fetch(self, address):
#         #string query params
#         params ={
#             'q': address,
#             'format': 'geocodejson'
#         }
#         res = requests.get(url = self.base_url, params = params)
#         print('Status code: {}'.format(res.status_code))
#
#         if(res.status_code == 200):
#             return res
#         else:
#             return ''
#
#     def parse(self, res):
#         try:
#
#             label = json.dumps(res['features'][0]['properties']['geocoding']['label'], indent = 2)
#             coordinates = json.dumps(res['features'][0]['geometry']['coordinates'], indent = 2).replace('\n', '').replace('[', '').replace(']', '').strip().split(',')
#             obj = {
#                 'label': label,
#                 'coordinates': coordinates
#             }
#             return (label, coordinates);
#         except:
#             return ('', ['','']);
#
#
#
#     def run(self, address):
#         print(address)
#         res = self.fetch(address).json()
#         time.sleep(1)
#         return self.parse(res)
#
# geocoder = Geocoder()
#
# label=[]
# coordinates = []
# for address in  df.iloc[indexNotGeolocated,0]:
#     lab, coor = geocoder.run(str(address))
#     label.append(lab)
#     coordinates.append(coor)

# %% [raw]
# df.iloc[indexNotGeolocated,6] = label

# %% [raw]
# # converto keyword in list_keyword
# #df.iloc[indexNotGeolocated,5] = df2020["keywords"].apply(lambda x: re.findall('\'([^\']*)\'', x)) # Transform string into list
# # creo latitude e longitude
# df.iloc[indexNotGeolocated,9] = pd.Series(coordinates)
# df.iloc[indexNotGeolocated,9] = df.iloc[indexNotGeolocated,9].apply(lambda x: re.findall('\'([^\']*)\'', str(x)))
#
# df.iloc[indexNotGeolocated,7] = df.iloc[indexNotGeolocated,9].apply(lambda x: x[0] if len(x)>0 else 0.0)
# df.iloc[indexNotGeolocated,3] = df.iloc[indexNotGeolocated,9].apply(lambda x: x[1] if len(x)>0 else 0.0)

# %% [raw]
# df.to_csv('data/toAnalyse.csv', index = False)

# %% [raw]
# dfAddressed = df[pd.notna(df['address'])]

# %% [raw]
# dfNotGeolocated = dfAddressed[dfAddressed['location'] == '']
# dfNotGeolocated

# %% [markdown]
# # Inserisco i quartieri
# Considero un altro dataset preso da trentino opendata polisociali.zip che contiene al suo interno la forma di ogni quartiere di trento, al fine di migliorare la qualitá delle informazioni che ho al mio dataset, cerco di identificare in quale quartiere é stata creata una determinata notizia, in modo da poter fare una analisi geografica.

# %%
from shapely import wkt
import geopandas as gpd
#df_quartieri = pd.read_csv('data/poli_sociali.csv', delimiter=';')
#df_quartieri = geopandas.read_file('data/poli_sociali.csv')
# loading polygons geodataframe
gdf_polygons = gpd.read_file('data/poli_sociali/poli_sociali.shp')
gdf_points = gpd.GeoDataFrame(
    df, geometry=geopandas.points_from_xy(df.longitude, df.latitude))

# %%
gdf_polygons
# Out:
#         area  cod_quart               nome_quart  cod_polo  \
# 0     244180         21                SAN PIO X         3
# 1    1517895          6            CAMPOTRENTINO         2
# 2     550103         28           SAN BARTOLOMEO         4
# 3    7356368         31               VILLAZZANO         5
# 4    1969068         27                  CLARINA         4
# 5     365695          8                    MELTA         1
# 6     565515         10                   CANOVA         1
# 7    1101422          4      SOLTERI-CENTOCHIAVI         2
# 8     143676         34          SAN DONA'-LASTE         5
# 9    2765516         12             SPINI-GHIAIE         1
# 10    569254          3                CRISTO RE         2
# 11    612363          1           CENTRO STORICO         2
# 12    246307         23           SAN BERNARDINO         3
# 13     32066         45      CAMPO NOMADI RAVINA         3
# 14    195598         18              SAN LAZZARO         1
# 15  10141977         32                     POVO         5
# 16  11325854         43                   RAVINA         3
# 17    389013         22               SANTISSIMO         3
# 18  24161906         41               SOPRAMONTE         2
# 19  14992240         46               MATTARELLO         4
# 20   2360963         11                RONCAFORT         1
# 21   1719623         29           MADONNA BIANCA         4
# 22   1488540         30             VILLAZZANO 3         4
# 23   2206710          9                  GARDOLO         1
# 24   1657983         17                GAZZADINA         1
# 25   2332824         16                    MEANO         1
# 26   4068885         14                CORTESANO         1
# 27   5632563         37               MARTIGNANO         5
# 28    697530         15         GARDOLO DI MEZZO         1
# 29    488552          2              SAN MARTINO         2
# 30   8654976         42                 SARDAGNA         2
# 31    553406         13                    LAMAR         1
# 32   2763813          7                  LA VELA         2
# 33   1533367          5            PIEDICASTELLO         2
# 34   1608775         20             SAN GIUSEPPE         3
# 35   6753461         19               VIGO MEANO         1
# 36   1406995         47                 VALSORDA         4
# 37   5314093         33            OLTRECASTELLO         5
# 38   7263132         38                   CADINE         2
# 39   5328107         44                ROMAGNANO         3
# 40   3600020         36            VILLAMONTAGNA         5
# 41   3313785         35                  COGNOLA         5
# 42    482691         25               CAPPUCCINI         3
# 43   2458144         40      BASELGA DEL BONDONE         2
# 44    499750         34          SAN DONA'-LASTE         5
# 45    102714         24  BELVEDERE-SAN FRANCESCO         3
# 46   1234382         26                 BOLGHERA         4
# 47   3074714         39           VIGOLO BASELGA         2
#
#                                               fumetto  perimetro  \
# 0   Quartiere SAN PIO X nel polo sociale S.GIUSEPP...       2404
# 1   Quartiere CAMPOTRENTINO nel polo sociale CENTR...       5807
# 2   Quartiere SAN BARTOLOMEO nel polo sociale OLTR...       4403
# 3   Quartiere VILLAZZANO nel polo sociale ARGENTAR...      15014
# 4   Quartiere CLARINA nel polo sociale OLTREFERSIN...       7958
# 5    Quartiere MELTA nel polo sociale GARDOLO E MEANO       2869
# 6   Quartiere CANOVA nel polo sociale GARDOLO E MEANO       3584
# 7   Quartiere SOLTERI-CENTOCHIAVI nel polo sociale...       4689
# 8   Quartiere SAN DONA'-LASTE nel polo sociale ARG...       2598
# 9   Quartiere SPINI-GHIAIE nel polo sociale GARDOL...       7806
# 10  Quartiere CRISTO RE nel polo sociale CENTRO ST...       4052
# 11  Quartiere CENTRO STORICO nel polo sociale CENT...       3427
# 12  Quartiere SAN BERNARDINO nel polo sociale S.GI...       2352
# 13  Quartiere CAMPO NOMADI RAVINA nel polo sociale...        703
# 14  Quartiere SAN LAZZARO nel polo sociale GARDOLO...       2603
# 15  Quartiere POVO nel polo sociale ARGENTARIO, PO...      19371
# 16  Quartiere RAVINA nel polo sociale S.GIUSEPPE-S...      17657
# 17  Quartiere SANTISSIMO nel polo sociale S.GIUSEP...       3620
# 18  Quartiere SOPRAMONTE nel polo sociale CENTRO S...      29413
# 19  Quartiere MATTARELLO nel polo sociale OLTREFER...      23413
# 20  Quartiere RONCAFORT nel polo sociale GARDOLO E...       9047
# 21  Quartiere MADONNA BIANCA nel polo sociale OLTR...       8038
# 22  Quartiere VILLAZZANO 3 nel polo sociale OLTREF...       7943
# 23  Quartiere GARDOLO nel polo sociale GARDOLO E M...       9743
# 24  Quartiere GAZZADINA nel polo sociale GARDOLO E...       9730
# 25   Quartiere MEANO nel polo sociale GARDOLO E MEANO       9008
# 26  Quartiere CORTESANO nel polo sociale GARDOLO E...      10383
# 27  Quartiere MARTIGNANO nel polo sociale ARGENTAR...      15405
# 28  Quartiere GARDOLO DI MEZZO nel polo sociale GA...       3381
# 29  Quartiere SAN MARTINO nel polo sociale CENTRO ...       3946
# 30  Quartiere SARDAGNA nel polo sociale CENTRO STO...      16320
# 31   Quartiere LAMAR nel polo sociale GARDOLO E MEANO       5155
# 32  Quartiere LA VELA nel polo sociale CENTRO STOR...      13970
# 33  Quartiere PIEDICASTELLO nel polo sociale CENTR...      11947
# 34  Quartiere SAN GIUSEPPE nel polo sociale S.GIUS...       7528
# 35  Quartiere VIGO MEANO nel polo sociale GARDOLO ...      12339
# 36  Quartiere VALSORDA nel polo sociale OLTREFERSI...       5066
# 37  Quartiere OLTRECASTELLO nel polo sociale ARGEN...       9919
# 38  Quartiere CADINE nel polo sociale CENTRO STORI...      13169
# 39  Quartiere ROMAGNANO nel polo sociale S.GIUSEPP...      17146
# 40  Quartiere VILLAMONTAGNA nel polo sociale ARGEN...      13494
# 41  Quartiere COGNOLA nel polo sociale ARGENTARIO,...       8979
# 42  Quartiere CAPPUCCINI nel polo sociale S.GIUSEP...       4250
# 43  Quartiere BASELGA DEL BONDONE nel polo sociale...       9093
# 44  Quartiere SAN DONA'-LASTE nel polo sociale ARG...       5255
# 45  Quartiere BELVEDERE-SAN FRANCESCO nel polo soc...       2398
# 46  Quartiere BOLGHERA nel polo sociale OLTREFERSI...       6582
# 47  Quartiere VIGOLO BASELGA nel polo sociale CENT...      13389
#
#                                             nome_polo sigla  simbolo_at  \
# 0              S.GIUSEPPE-S.CHIARA E RAVINA-ROMAGNANO  TN 3         NaN
# 1   CENTRO STORICO, PIEDICASTELLO, BONDONE E SARDAGNA  TN 6         NaN
# 2                           OLTREFERSINA E MATTARELLO  TN 4        44.0
# 3                       ARGENTARIO, POVO E VILLAZZANO  TN 1        12.0
# 4                           OLTREFERSINA E MATTARELLO  TN 4         4.0
# 5                                     GARDOLO E MEANO  TN 7         6.0
# 6                                     GARDOLO E MEANO  TN 7         6.0
# 7   CENTRO STORICO, PIEDICASTELLO, BONDONE E SARDAGNA  TN 5         6.0
# 8                       ARGENTARIO, POVO E VILLAZZANO  TN 2        12.0
# 9                                     GARDOLO E MEANO  TN 7         6.0
# 10  CENTRO STORICO, PIEDICASTELLO, BONDONE E SARDAGNA  TN 6         NaN
# 11  CENTRO STORICO, PIEDICASTELLO, BONDONE E SARDAGNA  TN 3         NaN
# 12             S.GIUSEPPE-S.CHIARA E RAVINA-ROMAGNANO  TN 3         NaN
# 13             S.GIUSEPPE-S.CHIARA E RAVINA-ROMAGNANO  TN 3         3.0
# 14                                    GARDOLO E MEANO  TN 7         6.0
# 15                      ARGENTARIO, POVO E VILLAZZANO  TN 1        12.0
# 16             S.GIUSEPPE-S.CHIARA E RAVINA-ROMAGNANO  TN 3         3.0
# 17             S.GIUSEPPE-S.CHIARA E RAVINA-ROMAGNANO  TN 3         NaN
# 18  CENTRO STORICO, PIEDICASTELLO, BONDONE E SARDAGNA  TN 6        66.0
# 19                          OLTREFERSINA E MATTARELLO  TN 8        44.0
# 20                                    GARDOLO E MEANO  TN 6         6.0
# 21                          OLTREFERSINA E MATTARELLO  TN 4        44.0
# 22                          OLTREFERSINA E MATTARELLO  TN 4        44.0
# 23                                    GARDOLO E MEANO  TN 7         6.0
# 24                                    GARDOLO E MEANO  TN 7         6.0
# 25                                    GARDOLO E MEANO  TN 7         6.0
# 26                                    GARDOLO E MEANO  TN 7         6.0
# 27                      ARGENTARIO, POVO E VILLAZZANO  TN 2        12.0
# 28                                    GARDOLO E MEANO  TN 7         6.0
# 29  CENTRO STORICO, PIEDICASTELLO, BONDONE E SARDAGNA  TN 5         NaN
# 30  CENTRO STORICO, PIEDICASTELLO, BONDONE E SARDAGNA  TN 6        66.0
# 31                                    GARDOLO E MEANO  TN 7         6.0
# 32  CENTRO STORICO, PIEDICASTELLO, BONDONE E SARDAGNA  TN 6         NaN
# 33  CENTRO STORICO, PIEDICASTELLO, BONDONE E SARDAGNA  TN 6         NaN
# 34             S.GIUSEPPE-S.CHIARA E RAVINA-ROMAGNANO  TN 3         NaN
# 35                                    GARDOLO E MEANO  TN 7         6.0
# 36                          OLTREFERSINA E MATTARELLO  TN 8         NaN
# 37                      ARGENTARIO, POVO E VILLAZZANO  TN 1        12.0
# 38  CENTRO STORICO, PIEDICASTELLO, BONDONE E SARDAGNA  TN 6        66.0
# 39             S.GIUSEPPE-S.CHIARA E RAVINA-ROMAGNANO  TN 8         3.0
# 40                      ARGENTARIO, POVO E VILLAZZANO  TN 2        12.0
# 41                      ARGENTARIO, POVO E VILLAZZANO  TN 2        12.0
# 42             S.GIUSEPPE-S.CHIARA E RAVINA-ROMAGNANO  TN 5         NaN
# 43  CENTRO STORICO, PIEDICASTELLO, BONDONE E SARDAGNA  TN 6        66.0
# 44                      ARGENTARIO, POVO E VILLAZZANO  TN 2        12.0
# 45             S.GIUSEPPE-S.CHIARA E RAVINA-ROMAGNANO  TN 5         NaN
# 46                          OLTREFERSINA E MATTARELLO  TN 3        44.0
# 47  CENTRO STORICO, PIEDICASTELLO, BONDONE E SARDAGNA  TN 6        66.0
#
#     simbolo2-a                                           geometry
# 0          5.0  POLYGON ((664351.625 5102511.000, 664256.750 5...
# 1          5.0  POLYGON ((663035.917 5106708.823, 663192.438 5...
# 2          NaN  POLYGON ((665214.735 5101925.368, 665242.003 5...
# 3          NaN  POLYGON ((665497.049 5102617.690, 665502.035 5...
# 4          NaN  POLYGON ((664147.125 5102159.000, 664223.750 5...
# 5          7.0  POLYGON ((663870.532 5107670.779, 663952.038 5...
# 6          7.0  POLYGON ((662448.562 5107668.500, 662470.938 5...
# 7          5.0  POLYGON ((664014.141 5106760.801, 664022.761 5...
# 8          NaN  POLYGON ((664296.891 5105785.202, 664299.943 5...
# 9          7.0  POLYGON ((661000.290 5110098.597, 661002.582 5...
# 10         5.0  POLYGON ((663673.000 5105667.500, 663788.000 5...
# 11         5.0  POLYGON ((663919.000 5104429.500, 663992.000 5...
# 12         5.0  POLYGON ((664462.125 5103717.500, 664487.375 5...
# 13         5.0  POLYGON ((664187.703 5100517.378, 664020.375 5...
# 14        77.0  POLYGON ((663897.312 5111987.500, 663897.312 5...
# 15         NaN  POLYGON ((666755.672 5104893.390, 666754.345 5...
# 16         5.0  POLYGON ((663312.544 5102745.129, 663318.651 5...
# 17         5.0  POLYGON ((664383.750 5103533.000, 664589.625 5...
# 18         5.0  POLYGON ((661635.371 5104958.409, 661630.600 5...
# 19       444.0  POLYGON ((664683.921 5099422.918, 664704.417 5...
# 20         7.0  POLYGON ((660989.228 5109609.594, 660981.253 5...
# 21       444.0  POLYGON ((665330.938 5100672.500, 665342.062 5...
# 22       444.0  POLYGON ((665781.800 5100751.928, 665782.861 5...
# 23         7.0  POLYGON ((663184.736 5109294.622, 663179.726 5...
# 24        77.0  POLYGON ((663813.941 5112027.883, 663821.014 5...
# 25        77.0  POLYGON ((663897.312 5111987.500, 663981.312 5...
# 26        77.0  POLYGON ((664567.062 5110490.000, 665015.188 5...
# 27         NaN  POLYGON ((663897.636 5108506.513, 663962.962 5...
# 28        77.0  POLYGON ((663987.062 5109307.000, 663963.312 5...
# 29         5.0  POLYGON ((664295.969 5105467.420, 664306.529 5...
# 30         5.0  POLYGON ((662632.498 5102939.146, 662634.560 5...
# 31         7.0  POLYGON ((662989.845 5111241.319, 663252.152 5...
# 32         5.0  POLYGON ((660806.164 5108265.785, 660785.809 5...
# 33         5.0  POLYGON ((663391.875 5105119.500, 663401.375 5...
# 34         5.0  POLYGON ((663883.625 5103639.500, 663900.875 5...
# 35        77.0  POLYGON ((664567.062 5110490.000, 664551.812 5...
# 36         NaN  POLYGON ((666974.784 5098164.061, 666977.290 5...
# 37         NaN  POLYGON ((666755.672 5104893.390, 666765.461 5...
# 38         5.0  POLYGON ((658843.180 5106283.127, 658838.023 5...
# 39         5.0  POLYGON ((660698.024 5098784.436, 660883.375 5...
# 40         NaN  POLYGON ((665629.625 5107082.000, 665609.000 5...
# 41         NaN  POLYGON ((665629.625 5107082.000, 665894.750 5...
# 42         5.0  POLYGON ((664754.724 5104844.472, 664760.521 5...
# 43         5.0  POLYGON ((658866.000 5105490.500, 658827.625 5...
# 44         NaN  POLYGON ((664754.724 5104844.472, 664857.250 5...
# 45         5.0  POLYGON ((664462.125 5103717.500, 664535.000 5...
# 46         NaN  POLYGON ((665434.173 5103910.674, 665441.164 5...
# 47         5.0  POLYGON ((658866.000 5105490.500, 658840.250 5...

# %%
#df_quartieri['WKT'] = df_quartieri['WKT'].apply(wkt.loads)
gdf_polygons.plot(figsize=(15,15), 
                  column='nome_quart',
                  legend=True)
#gdf_points.head()
# Out:
# <AxesSubplot:>

# %%
gdf_points.crs

# %% [markdown]
# Dai risultati emersi sono geolocalizzabili 18.617 elementi. Di questi voglio sapere i quartieri. Per fare questo devo trasformare il mio dataframe in geodataframe. In questo modo avró i miei punti formati.
# Fatto questo per ogni punto devo interrogare l'altro dataframe per vedere in che quartiere é, assegnargli poi il quartiere. Devo fare bene questa fase perché devo ancora capire quale informazione devo riportare nel mio df.
# Per il momento scelgo di inserire una colonna Nome_Quartiere id_quartiere

# %%
dfplus = geopandas.sjoin(gdf_points, gdf_polygons, how="left", op='within')
dfplus.columns
# Out:
# Index(['address', 'day', 'keywords', 'latitude', 'link', 'list_keywords',
#        'location', 'longitude', 'month', 'point', 'subtitle', 'text',
#        'timestamp', 'title', 'year', 'geometry', 'index_right', 'area',
#        'cod_quart', 'nome_quart', 'cod_polo', 'fumetto', 'perimetro',
#        'nome_polo', 'sigla', 'simbolo_at', 'simbolo2-a'],
#       dtype='object')

# %%
#dfplus[(dfplus['area'].notnull())].plot()
#gdf_polygons[gdf_polygons['nome_quart'] == 'CENTRO STORICO'].plot(figsize=(20,20))

# %% [markdown]
# Prossimo passo é inserire nel dataset l'informazione sulla città. Farò quello che ho fatto con i quartieri per tutto il trentino. In questo modo avró una informazione completa su ogni punto. Il dataset che utilizzo é quello dell'istat

# %%
import fiona
fiona.listlayers('data/istat_administrative_units_2020.gpkg')
municipalities = gpd.read_file("data/istat_administrative_units_2020.gpkg",layer="municipalities")
# filter the province
municipalities_province_trento = municipalities[municipalities.COD_PROV==22]
municipalities_province_trento.to_crs("EPSG:4326", inplace=True)
# Out:
# ['municipalities', 'provincies', 'regions', 'macroregions']

# %%
municipalities_province_trento.head()
# Out:
#       COD_RIP  COD_REG  COD_PROV  COD_CM  COD_UTS  PRO_COM PRO_COM_T  \
# 1257        2        4        22       0       22    22089    022089
# 1258        2        4        22       0       22    22090    022090
# 1259        2        4        22       0       22    22091    022091
# 1260        2        4        22       0       22    22092    022092
# 1261        2        4        22       0       22    22093    022093
#
#              COMUNE COMUNE_A  CC_UTS  \
# 1257        Fornace     None       0
# 1258    Frassilongo     None       0
# 1259  Garniga Terme     None       0
# 1260          Giovo     None       0
# 1261       Giustino     None       0
#
#                                                geometry
# 1257  MULTIPOLYGON (((11.21929 46.12242, 11.22091 46...
# 1258  MULTIPOLYGON (((11.30778 46.09674, 11.31344 46...
# 1259  MULTIPOLYGON (((11.06351 46.02184, 11.07263 46...
# 1260  MULTIPOLYGON (((11.18365 46.22580, 11.20165 46...
# 1261  MULTIPOLYGON (((10.73392 46.21327, 10.74632 46...

# %%
municipalities_province_trento.columns
# Out:
# Index(['COD_RIP', 'COD_REG', 'COD_PROV', 'COD_CM', 'COD_UTS', 'PRO_COM',
#        'PRO_COM_T', 'COMUNE', 'COMUNE_A', 'CC_UTS', 'geometry'],
#       dtype='object')

# %%
gdfPlus = gpd.GeoDataFrame(
    dfplus, geometry=geopandas.points_from_xy(df.longitude, df.latitude))
gdfPlus = gdfPlus.drop(['index_right'], axis=1)

# %%
dfComplete = geopandas.sjoin(gdfPlus, municipalities_province_trento, how="left", op='within')

# %%
dfComplete[dfComplete['COMUNE'].notnull()].columns
# Out:
# Index(['address', 'day', 'keywords', 'latitude', 'link', 'list_keywords',
#        'location', 'longitude', 'month', 'point', 'subtitle', 'text',
#        'timestamp', 'title', 'year', 'geometry', 'area', 'cod_quart',
#        'nome_quart', 'cod_polo', 'fumetto', 'perimetro', 'nome_polo', 'sigla',
#        'simbolo_at', 'simbolo2-a', 'index_right', 'COD_RIP', 'COD_REG',
#        'COD_PROV', 'COD_CM', 'COD_UTS', 'PRO_COM', 'PRO_COM_T', 'COMUNE',
#        'COMUNE_A', 'CC_UTS'],
#       dtype='object')

# %%
cols = ['timestamp', 'day', 'month', 'year', 'list_keywords', 'keywords','title','subtitle','text',
        'address','location','geometry','latitude','longitude',
        'cod_quart','nome_quart','PRO_COM','COMUNE']
dfComplete = dfComplete[cols]
dfComplete.rename(columns=str.lower, inplace=True)
dfComplete.to_csv('data/complete.csv', index=False)
