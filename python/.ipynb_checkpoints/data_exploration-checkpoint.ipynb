# %%
#!pip install pandas
#!pip install folium
#!pip install matplotlib

# %%
import pandas as pd
import folium
import numpy as np
import datetime
import re
import csv
from collections import Counter
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
from nltk.corpus import stopwords
from sklearn.feature_extraction.text import TfidfVectorizer
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/frabatx/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# # UNIFIED DATASET
# Il df che utilizzo dal 20/10/2020 ha il testo giá processato.

# %%
#df = pd.read_csv('trento/trento_total.csv',delimiter=',')
df = pd.read_csv('trento/totalProcessed.csv',delimiter=',')
df
# Out:
#        Unnamed: 0                            address  day  \
# 0               0            Trento,Piazza del Duomo    8
# 1               1           Oltrefersina,Via Fersina    8
# 2               2  Oltrefersina,Largo Medaglie d'oro    7
# 3               3               Dro,Via Monte Casale    7
# 4               4               Dro,Via Monte Casale    7
# ...           ...                                ...  ...
# 28676       28676                                NaN    9
# 28677       28677                                NaN    9
# 28678       28678                                NaN    9
# 28679       28679                                NaN    9
# 28680       28680                                NaN    9
#
#                                                 keywords   latitude  \
# 0                   ['strade', 'trasporti', 'viabilità']  46.067647
# 1                      ['alpini', 'esercito', 'tamponi']        NaN
# 2               ['bollettino', 'contagi', 'coronavirus']        NaN
# 3      ['incidenti montagna', 'morti', 'morti in mont...  46.031499
# 4             ['ferrate', 'incidenti montagna', 'morti']  46.031499
# ...                                                  ...        ...
# 28676                                         ['lavoro']   0.000000
# 28677                                     ['tecnologie']   0.000000
# 28678                                      ['religione']   0.000000
# 28679                                      ['trasporti']   0.000000
# 28680                                        ['spaccio']   0.000000
#
#                                                     link  \
# 0      https://www.trentotoday.it/attualita/strada-bo...
# 1      https://www.trentotoday.it/attualita/esercito-...
# 2      https://www.trentotoday.it/cronaca/bollettino-...
# 3      https://www.trentotoday.it/cronaca/federica-ma...
# 4      https://www.trentotoday.it/cronaca/ragazza-mor...
# ...                                                  ...
# 28676  http://www.trentotoday.it/economia/progettone-...
# 28677  http://www.trentotoday.it/cronaca/internet-con...
# 28678  http://www.trentotoday.it/cronaca/moschea-gard...
# 28679  http://www.trentotoday.it/cronaca/piedibus-mea...
# 28680  http://www.trentotoday.it/cronaca/arresti-spac...
#
#                                            list_keywords  \
# 0                   ['Strade', 'Trasporti', 'Viabilità']
# 1                      ['Alpini', 'Esercito', 'Tamponi']
# 2               ['Bollettino', 'Contagi', 'Coronavirus']
# 3      ['Incidenti', 'Montagna', 'Morti', 'Morti', 'I...
# 4          ['Ferrate', 'Incidenti', 'Montagna', 'Morti']
# ...                                                  ...
# 28676                                         ['Lavoro']
# 28677                                     ['Tecnologie']
# 28678                                      ['Religione']
# 28679                                      ['Trasporti']
# 28680                                        ['Spaccio']
#
#                                                 location  longitude  month  \
# 0      "Piazza del Duomo, Centro storico Trento, Tren...  11.121092     11
# 1                                                    NaN        NaN     11
# 2                                                    NaN        NaN     11
# 3      "Monte Casale, Via Ferrata Ernesto Che Guevara...  10.927659     11
# 4      "Monte Casale, Via Ferrata Ernesto Che Guevara...  10.927659     11
# ...                                                  ...        ...    ...
# 28676                                                NaN   0.000000     11
# 28677                                                NaN   0.000000     11
# 28678                                                NaN   0.000000     11
# 28679                                                NaN   0.000000     11
# 28680                                                NaN   0.000000     11
#
#                                 point  \
# 0      ['11.1210924', '  46.0676474']
# 1                            ['', '']
# 2                            ['', '']
# 3       ['10.9276592', '  46.031499']
# 4       ['10.9276592', '  46.031499']
# ...                               ...
# 28676                 (0.0, 0.0, 0.0)
# 28677                 (0.0, 0.0, 0.0)
# 28678                 (0.0, 0.0, 0.0)
# 28679                 (0.0, 0.0, 0.0)
# 28680                 (0.0, 0.0, 0.0)
#
#                                                 subtitle  \
# 0      La strada sarà chiusa durante le operazioni di...
# 1      Operazione del Ministero della Difesa in suppo...
# 2      Non accenna a diminuire il contagio: ecco i da...
# 3      Tragico incidente sulla "Che Guevara", probabi...
# 4      Drammatico incidente alla ferrata Che Guevara,...
# ...                                                  ...
# 28676  I sindacati non hanno raggiunto l'intesa con l...
# 28677  Presenti a Trento oltre cento relatori per dis...
# 28678  La comunità musulmana trentina potrà utilizzar...
# 28679  Hanno già aderito trentasei bambini, suddivisi...
# 28680  Secondo le indagini rifornivano circa 50 consu...
#
#                                                     text   timestamp  \
# 0       strada chiusa trasporto alberi natale comune ...  2020/11/08
# 1       arriva trento punto tamponi gestito dall eser...  2020/11/08
# 2       accenna appiattirsi linea contagi trentino 25...  2020/11/07
# 3       federica marcolla, medico mamma bambini, la v...  2020/11/07
# 4       mattinata drammatica monte casale ragazza 32 ...  2020/11/07
# ...                                                  ...         ...
# 28676                                                nan  2011/11/09
# 28677                                                nan  2011/11/09
# 28678   gardolo centro islamico consiglio stato infat...  2011/11/09
# 28679   grazie disponibilità sedici genitori volontar...  2011/11/09
# 28680   laccusa avere spacciato cocaina zona giudicar...  2011/11/09
#
#                                                    title  year
# 0      Arrivano gli alberi di Natale: chiusa la strad...  2020
# 1              Tamponi: anche a Trento arriva l'esercito  2020
# 2      Bollettino coronavirus: 251 nuovi casi in Tren...  2020
# 3      Precipita in ferrata: morta Federica Marcolla,...  2020
# 4      Dro, precipita dalla ferrata per 200 metri e m...  2020
# ...                                                  ...   ...
# 28676  Progettone: niente accordo sugli stipendi dei ...  2011
# 28677  Le nuove frontiere di internet: due giorni di ...  2011
# 28678  Centro islamico a Gardolo: il Consiglio di Sta...  2011
# 28679  Piedibus: il servizio gratuito arriva anche a ...  2011
# 28680  Spaccio di cocaina in Trentino: arrestate nove...  2011
#
# [28681 rows x 16 columns]

# %% [markdown]
# # CHANGE TIMESTAMP FORMAT

# %% [raw]
# # Sacrifico l'orario poiché é l'ora della pubblicazione del articolo
# def funzioneConvertiData(stringa):
#     month = {	'gennaio':'01',
#                 'febbraio':'02',
#                 'marzo':'03',
#                 'aprile':'04',
#                 'maggio':'05',
#                 'giugno':'06',
#                 'luglio':'07',
#                 'agosto':'08',
#                 'settembre':'09',
#                 'ottobre':'10',
#                 'novembre':'11',
#                 'dicembre':'12'
#             }
#     for ita, eng in month.items():
#         stringa = stringa.replace(ita.lower(), eng)
#     return stringa
#
# def conversioneInData(stringa):
#     d = datetime.datetime.strptime(stringa, '%d %m %Y %H:%M')
#     year = d.strftime('%Y')
#     month = d.strftime('%m')
#     day = d.strftime('%d')
#     return d.strftime('%Y/%m/%d')
#
# df['timestamp'] =  df['timestamp'].apply(lambda x: funzioneConvertiData(x))
# df['timestamp'] =  df['timestamp'].apply(lambda x: conversioneInData(x))
# df['year'] = df['timestamp'].apply(lambda x: datetime.datetime.strptime(x, '%Y/%m/%d').strftime('%Y'))
# df['month'] = df['timestamp'].apply(lambda x: datetime.datetime.strptime(x, '%Y/%m/%d').strftime('%m'))
# df['day'] = df['timestamp'].apply(lambda x: datetime.datetime.strptime(x, '%Y/%m/%d').strftime('%d'))
# #df

# %% [markdown]
# # KEYWORDS UNICHE

# %% [raw]
# df = pd.read_csv('trento/dfTextProcessed3.csv',delimiter=',')

# %%
df["list_keywords"] = df["list_keywords"].apply(lambda x: re.findall('\'([^\']*)\'', x)) # Transform string into list

# %%
#Check unique keywords
def uniqueKeyword(listaInDataframe):
    #df_temp = df[df['year']=='2019']
    temp_l = list(listaInDataframe)
    temp_l = [j for i in temp_l for j in i]
    cnt = Counter(temp_l)

    key_value_count = cnt.most_common()
    key_value_count.sort(key= lambda x: x[1], reverse=True)
    total_keywords = [(x,y) for x,y in key_value_count]
    #print(len(total_keywords))
    return total_keywords

total_keywords = uniqueKeyword(df["list_keywords"])
list(total_keywords)
# Out:
# [('Incidenti', 2866),
#  ('Argomenti', 2446),
#  ('Elezioni', 1003),
#  ('Montagna', 986),
#  ('Coronavirus', 932),
#  ('Lavoro', 899),
#  ('Strade', 893),
#  ('Morti', 865),
#  ('Del', 798),
#  ('Furti', 780),
#  ('Viabilità', 741),
#  ('Scuola', 732),
#  ('Trento', 730),
#  ('Carabinieri', 656),
#  ('Trasporti', 635),
#  ('Ambiente', 615),
#  ('Basket', 613),
#  ('Meteo', 593),
#  ('Droga', 570),
#  ('Università', 561),
#  ('Notizie', 536),
#  ('Curiose', 536),
#  ('Trentino', 516),
#  ('Di', 515),
#  ('Incendi', 504),
#  ('Sanità', 502),
#  ('Sport', 487),
#  ('Animali', 475),
#  ('Volley', 475),
#  ('Comunali', 470),
#  ('Vigili', 463),
#  ('Polizia', 460),
#  ('Fuoco', 460),
#  ('Politica', 436),
#  ('Traffico', 431),
#  ('Comune', 430),
#  ('Provincia', 403),
#  ('Turismo', 403),
#  ('Sci', 401),
#  ('Pubblici', 399),
#  ('Lavori', 390),
#  ('Orso', 374),
#  ('Neve', 367),
#  ('Agricoltura', 344),
#  ('Soccorso', 333),
#  ('Sindacati', 323),
#  ('Brennero', 320),
#  ('Calcio', 315),
#  ('Alpino', 307),
#  ('Economia', 298),
#  ('Casa', 295),
#  ('Rifiuti', 293),
#  ('Aquila', 292),
#  ('Salute', 290),
#  ('Provinciali', 290),
#  ('Natale', 282),
#  ('Elisoccorso', 281),
#  ('2013', 279),
#  ('Natura', 278),
#  ('A22', 273),
#  ('Stradali', 269),
#  ('Maltempo', 266),
#  ('Autostrada', 264),
#  ('Arresti', 262),
#  ('Musica', 260),
#  ('Tribunale', 256),
#  ('Mercatini', 251),
#  ('Consiglio', 248),
#  ('Truffe', 236),
#  ('Giovani', 235),
#  ('2018', 235),
#  ('Eventi', 234),
#  ('Scioperi', 233),
#  ('Feste', 232),
#  ('Guardia', 231),
#  ('Storia', 229),
#  ('Weekend', 226),
#  ('Provinciale', 221),
#  ('Mobilità', 219),
#  ('Studenti', 213),
#  ('Festival', 209),
#  ('2015', 209),
#  ('Internet', 205),
#  ('Civile', 201),
#  ('Immigrazione', 201),
#  ('Violenza', 198),
#  ('Aziende', 197),
#  ('Dati', 196),
#  ('Treni', 195),
#  ('Locale', 194),
#  ('Patente', 193),
#  ('Finanza', 192),
#  ('Cultura', 190),
#  ('Omicidio', 190),
#  ('Rovereto', 189),
#  ('Commercio', 188),
#  ('Solidarietà', 188),
#  ('Sicurezza', 187),
#  ('Manifestazioni', 185),
#  ('Rossi', 184),
#  ('Comuni', 183),
#  ('Protezione', 181),
#  ('Contributi', 181),
#  ('Alpini', 180),
#  ('Indagini', 178),
#  ('Fugatti', 177),
#  ('Minori', 176),
#  ('Ugo', 175),
#  ('Tasse', 175),
#  ('Rapine', 174),
#  ('Garda', 171),
#  ('Motociclistici', 169),
#  ('Adunata', 169),
#  ('Incidente', 166),
#  ('Concerti', 166),
#  ('Piazza', 163),
#  ('Scienza', 162),
#  ('Maurizio', 161),
#  ('Consumatori', 158),
#  ('Autobus', 158),
#  ('Sul', 156),
#  ('Dolomiti', 155),
#  ('Estate', 154),
#  ('Tecnologie', 154),
#  ('Denunciati', 153),
#  ('Servizi', 152),
#  ('Proteste', 152),
#  ('Donne', 152),
#  ('Diritti', 148),
#  ('Alessandro', 147),
#  ('Controlli', 146),
#  ('Ricerca', 145),
#  ('Profughi', 144),
#  ('Anziani', 142),
#  ('Aggressioni', 142),
#  ('Polemiche', 142),
#  ('Incendio', 141),
#  ('Sindaco', 141),
#  ('Cooperazione', 141),
#  ('Degrado', 140),
#  ('Piste', 139),
#  ('Urbanistica', 138),
#  ('Alcol', 138),
#  ('Inquinamento', 134),
#  ('Politiche', 133),
#  ('2020', 131),
#  ('Auto', 130),
#  ('Parchi', 130),
#  ('Esteri', 129),
#  ('Locali', 128),
#  ('Famiglia', 128),
#  ('Alpinismo', 128),
#  ('118', 126),
#  ('Trasporto', 126),
#  ('Caccia', 124),
#  ('Lago', 124),
#  ('Investimenti', 124),
#  ('Film', 122),
#  ('Furto', 120),
#  ('Autonomia', 120),
#  ('Della', 118),
#  ('Centro', 118),
#  ('Spaccio', 117),
#  ('Sciopero', 116),
#  ('Ferrovie', 115),
#  ('Orsi', 114),
#  ('Violenze', 114),
#  ('Cinema', 114),
#  ('Sociali', 112),
#  ('Viaggi', 111),
#  ('Imprese', 110),
#  ('Sociale', 110),
#  ('Giustizia', 109),
#  ('Ospedale', 107),
#  ('Bruno', 106),
#  ('Moto', 106),
#  ('Valsugana', 106),
#  ('Asili', 105),
#  ('Energia', 105),
#  ('Salvini', 105),
#  ('Lega', 104),
#  ('Referendum', 104),
#  ('Medicina', 104),
#  ('Vandalismi', 104),
#  ('Ciclismo', 104),
#  ('Adige', 103),
#  ('Armi', 102),
#  ('Arte', 101),
#  ('Scomparsi', 101),
#  ('Musei', 100),
#  ('Chiesa', 99),
#  ('Guerra', 99),
#  ('Frane', 99),
#  ('Asilo', 98),
#  ('Candidati', 98),
#  ('Cani', 97),
#  ('Parcheggi', 97),
#  ('Cannabis', 96),
#  ('Valanghe', 93),
#  ('Matteo', 93),
#  ('Informazioni', 93),
#  ('Alto', 91),
#  ('Concorsi', 91),
#  ('Forestale', 90),
#  ('Risse', 90),
#  ('Interrogazioni', 90),
#  ('Lupo', 88),
#  ('Tav', 88),
#  ('Vitalizi', 88),
#  ('Fotografia', 86),
#  ('Valdastico', 86),
#  ('Anarchici', 85),
#  ('Infanzia', 85),
#  ('Nord', 84),
#  ('Richiedenti', 84),
#  ('Classifiche', 84),
#  ('2014', 84),
#  ('Migranti', 83),
#  ('Covid', 82),
#  ('Muse', 82),
#  ('Camion', 82),
#  ('Terremoti', 82),
#  ('Contagi', 81),
#  ('Attentato', 81),
#  ('Mortali', 80),
#  ('Storico', 80),
#  ('Elicottero', 79),
#  ('Samantha', 79),
#  ('Tangenziale', 78),
#  ('Banche', 78),
#  ('Biciclette', 78),
#  ('Cristoforetti', 78),
#  ('Olimpiadi', 77),
#  ('Daniza', 76),
#  ('Volontariato', 76),
#  ('Scandalo', 75),
#  ('Pubbliche', 74),
#  ('Movida', 74),
#  ('Risparmiare', 74),
#  ('Sportivi', 74),
#  ('Enogastronomia', 74),
#  ('Vaccini', 73),
#  ('Portela', 73),
#  ('Edilizia', 73),
#  ('Giunta', 72),
#  ('Movimento', 72),
#  ('Stelle', 72),
#  ('Da', 71),
#  ('Olivi', 71),
#  ('Franco', 70),
#  ('Bondone', 70),
#  ('Giornalismo', 69),
#  ('Rifugi', 69),
#  ('Terremoto', 69),
#  ('Infortunio', 69),
#  ('Multe', 68),
#  ('Grande', 68),
#  ('Terrorismo', 68),
#  ('Bambini', 67),
#  ('Raccolta', 67),
#  ('Libri', 67),
#  ('Dispersi', 66),
#  ('Andreatta', 66),
#  ('Luca', 65),
#  ('Paolo', 65),
#  ('Dante', 65),
#  ('Vino', 65),
#  ('Capodanno', 65),
#  ('Crisi', 64),
#  ('Opere', 64),
#  ('Michele', 64),
#  ('Ciclabili', 64),
#  ('Malattie', 64),
#  ('Pubblica', 64),
#  ('Mauro', 64),
#  ('Dpcm', 63),
#  ('Nel', 63),
#  ('Sessuale', 63),
#  ('Nascita', 63),
#  ('Dei', 62),
#  ('Governo', 62),
#  ('Valle', 62),
#  ('Bosco', 62),
#  ('Gratis', 62),
#  ('Comunità', 61),
#  ('Ospedali', 61),
#  ('Beni', 61),
#  ('Punti', 61),
#  ('M49', 60),
#  ('Tamponi', 59),
#  ('In', 59),
#  ('Itea', 59),
#  ('Veneto', 59),
#  ('Europa', 59),
#  ('Gilmozzi', 59),
#  ('Smaltimento', 58),
#  ('Negozi', 57),
#  ('Laghi', 57),
#  ('Omosessuali', 57),
#  ('Lorenzo', 57),
#  ('Sagre', 57),
#  ('Comunale', 56),
#  ('Carcere', 56),
#  ('Differenziata', 56),
#  ('Acqua', 56),
#  ('Ricerche', 55),
#  ('Società', 55),
#  ('Partito', 55),
#  ('Spazio', 55),
#  ('Diego', 55),
#  ('Giuseppe', 54),
#  ('Roberto', 54),
#  ('Ristoranti', 54),
#  ('Facebook', 54),
#  ('Bicicletta', 54),
#  ('Stato', 53),
#  ('Trattore', 53),
#  ('Fisco', 52),
#  ('Santa', 52),
#  ('Motori', 52),
#  ('Supermercati', 51),
#  ('Teatro', 51),
#  ('Azzardo', 51),
#  ('Duomo', 51),
#  ('Fondazione', 51),
#  ('Riva', 50),
#  ('Marco', 50),
#  ('Monte', 50),
#  ('Video', 50),
#  ('Autunno', 50),
#  ('Renzi', 50),
#  ('No', 50),
#  ('Cooperative', 50),
#  ('Lupi', 49),
#  ('Questura', 49),
#  ('Bomba', 49),
#  ('Maltrattamenti', 49),
#  ('Previsioni', 49),
#  ('Ladri', 49),
#  ('Sostenibile', 49),
#  ('Filippo', 49),
#  ('Spesa', 49),
#  ('Democratico', 49),
#  ('Legge', 49),
#  ('Pubblico', 48),
#  ('Senza', 48),
#  ('Carnevale', 48),
#  ('Primavera', 48),
#  ('Dimora', 47),
#  ('Associazioni', 47),
#  ('Parapendio', 47),
#  ('Suicidi', 47),
#  ('Sait', 47),
#  ('Albere', 47),
#  ('Licenziamenti', 47),
#  ('Notte', 47),
#  ('Regione', 47),
#  ('Prostituzione', 46),
#  ('Bracconaggio', 46),
#  ('Poste', 46),
#  ('Mascherine', 45),
#  ('Biblioteche', 45),
#  ('Nido', 45),
#  ('Claudio', 45),
#  ('Annegamenti', 45),
#  ('Fascismo', 45),
#  ('Tiziano', 45),
#  ('Disoccupazione', 45),
#  ('Mellarini', 45),
#  ('Fusioni', 45),
#  ('Esplosioni', 44),
#  ('Base', 44),
#  ('Stranieri', 44),
#  ('Culturali', 44),
#  ('Petizioni', 44),
#  ('Inverno', 44),
#  ('Bilancio', 44),
#  ('Liste', 44),
#  ('Animalisti', 43),
#  ('Mafia', 43),
#  ('Dello', 43),
#  ('Carollo', 43),
#  ('Rurali', 43),
#  ('Vittorio', 43),
#  ('Istruzione', 43),
#  ('Pd', 43),
#  ('Dallapiccola', 43),
#  ('Focus', 43),
#  ('Antonio', 42),
#  ('Andrea', 42),
#  ('Vigiliane', 42),
#  ('Doping', 42),
#  ('Cibo', 42),
#  ('Itas', 42),
#  ('Casse', 42),
#  ('Re', 42),
#  ('San', 41),
#  ('Italia', 41),
#  ('Marijuana', 41),
#  ('Cocaina', 41),
#  ('Persone', 41),
#  ('Rapina', 41),
#  ('Francesco', 41),
#  ('Lingue', 41),
#  ('Dellai', 41),
#  ('Playoff', 41),
#  ('Pedoni', 40),
#  ('Mondiali', 40),
#  ('Carlo', 40),
#  ('25', 39),
#  ('Cassa', 39),
#  ('Televisione', 39),
#  ('Accoltellamento', 39),
#  ('Bolzano', 39),
#  ('Vento', 39),
#  ('Pesticidi', 39),
#  ('Mach', 39),
#  ('Tunnel', 39),
#  ('Borgonovo', 39),
#  ('Agenzia', 38),
#  ('Razzismo', 38),
#  ('Megalizzi', 38),
#  ('Periferici', 38),
#  ('De', 38),
#  ('Regionale', 38),
#  ('Moltrer', 38),
#  ('Primarie', 38),
#  ('Universiadi', 38),
#  ('Truffa', 37),
#  ('Domestici', 37),
#  ('Aprile', 37),
#  ('Memoria', 37),
#  ('Tv', 37),
#  ('Pedofilia', 37),
#  ('Bollettino', 36),
#  ('Panizza', 36),
#  ('Informatica', 36),
#  ('Demografia', 36),
#  ('Resistenza', 36),
#  ('Intossicazioni', 36),
#  ('Stradale', 36),
#  ('Aeroporto', 36),
#  ('Pound', 36),
#  ('Mercato', 36),
#  ('Molestie', 36),
#  ('Occupazione', 36),
#  ('Whirlpool', 36),
#  ('Donata', 36),
#  ('Presidente', 35),
#  ('Val', 35),
#  ('Delle', 35),
#  ('Sviluppo', 35),
#  ('Partiti', 35),
#  ('Welfare', 35),
#  ('Gossip', 35),
#  ('Appalti', 35),
#  ('Campionati', 35),
#  ('Consumi', 35),
#  ('Strada', 34),
#  ('Kompatscher', 34),
#  ('Foto', 34),
#  ('Scuole', 34),
#  ('Mart', 34),
#  ('Mostre', 34),
#  ('Sgarbi', 34),
#  ('Morto', 34),
#  ('Psicologia', 34),
#  ('Bianca', 34),
#  ('Costi', 34),
#  ('Patt', 34),
#  ('Prevenzione', 33),
#  ('Giorgio', 33),
#  ('Evasione', 33),
#  ('Bar', 33),
#  ('Chiara', 33),
#  ('Stalking', 33),
#  ('Bancomat', 33),
#  ('Fiumi', 33),
#  ('Cia', 33),
#  ('Caldo', 33),
#  ('Sequestri', 33),
#  ('Treno', 33),
#  ('Camera', 33),
#  ('Bandi', 33),
#  ('Trenitalia', 33),
#  ('Nomine', 33),
#  ('Chiusure', 32),
#  ('Minacce', 32),
#  ('Ianeselli', 32),
#  ('Danni', 32),
#  ('Giochi', 32),
#  ('Corte', 32),
#  ('Maria', 32),
#  ('Nuoto', 32),
#  ('Bici', 32),
#  ('Italiane', 32),
#  ('Archeologia', 32),
#  ('Rinnovabili', 32),
#  ('Conte', 31),
#  ('Tipici', 31),
#  ('Blocco', 31),
#  ('Vacanze', 31),
#  ('Degasperi', 31),
#  ('Unesco', 31),
#  ('Immobiliare', 31),
#  ('Disabili', 31),
#  ('Femminicidio', 31),
#  ('Statistica', 31),
#  ('Energie', 31),
#  ('Ottobre', 30),
#  ('Arno', 30),
#  ('Servizio', 30),
#  ('Innovazione', 30),
#  ('Usato', 30),
#  ('Prodotti', 30),
#  ('Verona', 30),
#  ('Procura', 30),
#  ('Agostino', 30),
#  ('Sergio', 30),
#  ('Reddito', 30),
#  ('Europee', 30),
#  ('Temporali', 30),
#  ('Studio', 30),
#  ('Fraccaro', 30),
#  ('Parco', 29),
#  ('Zeni', 29),
#  ('Albergatori', 29),
#  ('App', 29),
#  ('Circoscrizioni', 29),
#  ('Smarriti', 29),
#  ('Birra', 29),
#  ('Schützen', 29),
#  ('Alberto', 29),
#  ('Malaria', 29),
#  ('Riccardo', 29),
#  ('Danneggiamenti', 29),
#  ('Esercito', 28),
#  ('Offerte', 28),
#  ('Jumping', 28),
#  ('Anniversario', 28),
#  ('Scomparse', 28),
#  ('Borse', 28),
#  ('Trilingue', 28),
#  ('Redditi', 28),
#  ('Repubblica', 28),
#  ('Campagna', 28),
#  ('Dorigatti', 28),
#  ('Finanziaria', 28),
#  ('Freddo', 27),
#  ('Case', 27),
#  ('Porfido', 27),
#  ('Aereo', 27),
#  ('Bike', 27),
#  ('Austria', 27),
#  ('Omofobia', 27),
#  ('Mattarella', 27),
#  ('Fiera', 27),
#  ('Curiosità', 27),
#  ('Pioggia', 27),
#  ('Rock', 27),
#  ('Spettacoli', 27),
#  ('Religione', 27),
#  ('Baratter', 27),
#  ('Strongmanrun', 27),
#  ('Rsa', 26),
#  ('Apss', 26),
#  ('Alex', 26),
#  ('Bollette', 26),
#  ('Alberi', 26),
#  ('Aggressione', 26),
#  ('Fiscale', 26),
#  ('Corsi', 26),
#  ('Suoni', 26),
#  ('Senato', 26),
#  ('Vallo', 26),
#  ('Tomo', 26),
#  ('Lettere', 26),
#  ('Domestiche', 25),
#  ('Nuovo', 25),
#  ('Allerta', 25),
#  ('Entrate', 25),
#  ('Funghi', 25),
#  ('Rissa', 25),
#  ('Lucia', 25),
#  ('Acciaieria', 25),
#  ('Iniziative', 25),
#  ('Povertà', 25),
#  ('Rapinatori', 25),
#  ('Walter', 25),
#  ('Spazi', 25),
#  ('Italiani', 25),
#  ('Eroina', 24),
#  ('Sciistici', 24),
#  ('Fiere', 24),
#  ('Confindustria', 24),
#  ('Premi', 24),
#  ('Castelli', 24),
#  ('Cinque', 24),
#  ('Ferragosto', 24),
#  ('Funivie', 24),
#  ('Estorsione', 24),
#  ('Pensioni', 24),
#  ('Conti', 24),
#  ('Biblioteca', 24),
#  ('Illesi', 24),
#  ('Stelvio', 24),
#  ('Sat', 24),
#  ('Abbandonati', 24),
#  ('Tagli', 24),
#  ('Denuncia', 23),
#  ('Incontri', 23),
#  ('Integrazione', 23),
#  ('Postale', 23),
#  ('Mele', 23),
#  ('Frana', 23),
#  ('Industria', 23),
#  ('Grandine', 23),
#  ('Aerei', 23),
#  ('Ricercati', 23),
#  ('Maggiore', 23),
#  ('Dipendenti', 23),
#  ('Arrampicata', 23),
#  ('Allevamento', 23),
#  ('Alluvioni', 23),
#  ('Professioni', 23),
#  ('Corruzione', 23),
#  ('Ministero', 23),
#  ('Centrodestra', 23),
#  ('Zivignago', 23),
#  ('Carceri', 23),
#  ('Mosna', 23),
#  ('Test', 22),
#  ('Mirko', 22),
#  ('Piscine', 22),
#  ('Criminalità', 22),
#  ('Contromano', 22),
#  ('Assicurazioni', 22),
#  ('Casting', 22),
#  ('Affitti', 22),
#  ('Stefania', 22),
#  ('Maggio', 22),
#  ('Omicidi', 22),
#  ('Not', 22),
#  ('Ecologia', 22),
#  ('Abitazione', 22),
#  ('Marcialonga', 22),
#  ('Indennità', 22),
#  ('Nepal', 22),
#  ('Infrastrutture', 22),
#  ('Chiusi', 21),
#  ('Aperti', 21),
#  ('Casteller', 21),
#  ('Bisesti', 21),
#  ('Bonus', 21),
#  ('Ballottaggio', 21),
#  ('Smartphone', 21),
#  ('Cucina', 21),
#  ('Sardagna', 21),
#  ('Camper', 21),
#  ('Band', 21),
#  ('Expo', 21),
#  ('Schwazer', 21),
#  ('Arco', 20),
#  ('Chico', 20),
#  ('Forti', 20),
#  ('Pedopornografia', 20),
#  ('Cittadinanza', 20),
#  ('Sentieri', 20),
#  ('Giacomo', 20),
#  ('Codice', 20),
#  ('Passi', 20),
#  ('Pasqua', 20),
#  ('Ztl', 20),
#  ('Geologia', 20),
#  ('Acli', 20),
#  ('Telefonia', 20),
#  ('Delta', 20),
#  ('Riforme', 20),
#  ('Kostner', 20),
#  ('Bullismo', 19),
#  ('Reati', 19),
#  ('Ora', 19),
#  ('Asta', 19),
#  ('Carburanti', 19),
#  ('Soccorsi', 19),
#  ('Ex', 19),
#  ('Aeroporti', 19),
#  ('Zaia', 19),
#  ('Interviste', 19),
#  ('Corsa', 19),
#  ('Foibe', 19),
#  ('Inseguimento', 19),
#  ('Of', 19),
#  ('Pride', 19),
#  ('Protonterapia', 19),
#  ('Primo', 19),
#  ('Carolina', 19),
#  ('Contagio', 18),
#  ('Ferroviaria', 18),
#  ('La', 18),
#  ('Posti', 18),
#  ('Disabilità', 18),
#  ('Fondo', 18),
#  ('Chiuse', 18),
#  ('Mountain', 18),
#  ('Discoteca', 18),
#  ('Lavis', 18),
#  ('Matrimoni', 18),
#  ('Gay', 18),
#  ('Artigianato', 18),
#  ('Diritto', 18),
#  ('Marangoni', 18),
#  ('Evacuazioni', 18),
#  ('Papa', 18),
#  ('Architettura', 18),
#  ('Le', 18),
#  ('Luigi', 18),
#  ('Francesca', 18),
#  ('Sharing', 18),
#  ('Disegni', 18),
#  ('Halloween', 17),
#  ('Patrimonio', 17),
#  ('Green', 17),
#  ('Commercianti', 17),
#  ('Artigiani', 17),
#  ('Tentato', 17),
#  ('Saldi', 17),
#  ('Naturali', 17),
#  ('Insegnanti', 17),
#  ('Maturità', 17),
#  ('Autostrade', 17),
#  ('Cimitero', 17),
#  ('Pronto', 17),
#  ('Dolosi', 17),
#  ('Scippi', 17),
#  ('Vita', 17),
#  ('Bocconi', 17),
#  ('Avvelenati', 17),
#  ('Miracolati', 17),
#  ('Parlamentari', 17),
#  ('Ritiri', 17),
#  ('2019', 17),
#  ('Bastard', 17),
#  ('Sons', 17),
#  ('Dioniso', 17),
#  ('Ferrovia', 17),
#  ('Run', 17),
#  ('Centrosinistra', 17),
#  ('Arredamento', 17),
#  ('Legambiente', 17),
#  ('Occupazioni', 17),
#  ('Amministrazione', 17),
#  ('Ricettazione', 17),
#  ('Cso', 17),
#  ('Pergine', 16),
#  ('Riposo', 16),
#  ('Pullman', 16),
#  ('Pari', 16),
#  ('Opportunità', 16),
#  ('Farmacie', 16),
#  ('Risultati', 16),
#  ('Fiume', 16),
#  ('Upt', 16),
#  ('Atletica', 16),
#  ('Taccheggio', 16),
#  ('Nomadi', 16),
#  ('Tecnologia', 16),
#  ('Domiciliari', 16),
#  ('Social', 16),
#  ('Redazione', 16),
#  ('Valanga', 16),
#  ('Rugby', 16),
#  ('Quartiere', 16),
#  ('Torre', 16),
#  ('Eurocup', 16),
#  ('Serniotti', 16),
#  ('Divieti', 15),
#  ('Ordinanza', 15),
#  ('Neonati', 15),
#  ('Alberghi', 15),
#  ('Partecipate', 15),
#  ('Buonconsiglio', 15),
#  ('Emergenza', 15),
#  ('Mario', 15),
#  ('Collini', 15),
#  ('Nazismo', 15),
#  ('Segnana', 15),
#  ('Inps', 15),
#  ('Start', 15),
#  ('Up', 15),
#  ('Tirocini', 15),
#  ('Inchiesta', 15),
#  ('Daldoss', 15),
#  ('Paix', 15),
#  ('Progettone', 15),
#  ('Manuela', 15),
#  ('Color', 15),
#  ('Energy', 15),
#  ('Diatec', 15),
#  ('Casapound', 15),
#  ('Ordinanze', 14),
#  ('Il', 14),
#  ('Jj4', 14),
#  ('Stazione', 14),
#  ('Decreto', 14),
#  ('Malore', 14),
#  ('Impianti', 14),
#  ('Mori', 14),
#  ('Medici', 14),
#  ('Non', 14),
#  ('Oggetti', 14),
#  ('Ghiacciai', 14),
#  ('Vandali', 14),
#  ('Droghe', 14),
#  ('Primiero', 14),
#  ('Fiemme', 14),
#  ('Bordon', 14),
#  ('Qualità', 14),
#  ('Pattinaggio', 14),
#  ('Tradizioni', 14),
#  ('Sesso', 14),
#  ('Cantieri', 14),
#  ('Alimentazione', 14),
#  ('Bezzi', 14),
#  ('Palatrento', 14),
#  ('Euregio', 14),
#  ('Massimo', 14),
#  ('Disservizi', 14),
#  ('Quarta', 14),
#  ('Arresto', 13),
#  ('Sole', 13),
#  ('Aperture', 13),
#  ('Tempesta', 13),
#  ('Vaia', 13),
#  ('Borgo', 13),
#  ('Cavalese', 13),
#  ('Sequestro', 13),
#  ('Passo', 13),
#  ('Messner', 13),
#  ('Renato', 13),
#  ('Domenicali', 13),
#  ('Accoglienza', 13),
#  ('Eletti', 13),
#  ('Caduta', 13),
#  ('Frode', 13),
#  ('Europei', 13),
#  ('Festa', 13),
#  ('Legale', 13),
#  ('Snowboard', 13),
#  ('Maternità', 13),
#  ('Rifugiati', 13),
#  ('Autismo', 13),
#  ('Piero', 13),
#  ('Imu', 13),
#  ('Civica', 13),
#  ('Boni', 13),
#  ('Mondo', 13),
#  ('Car', 13),
#  ('Ferrari', 13),
#  ('2016', 13),
#  ('Pacher', 13),
#  ('Pulizia', 12),
#  ('Smart', 12),
#  ('Benessere', 12),
#  ('Influenza', 12),
#  ('Reinhold', 12),
#  ('Museo', 12),
#  ('Ciclabile', 12),
#  ('Giulia', 12),
#  ('Hotel', 12),
#  ('Soldi', 12),
#  ('Network', 12),
#  ('Giostre', 12),
#  ('Giornata', 12),
#  ('Clima', 12),
#  ('Riscaldamenti', 12),
#  ('Enrico', 12),
#  ('Posto', 12),
#  ('Buscaglia', 12),
#  ('Angela', 12),
#  ('Campionato', 12),
#  ('Crematorio', 12),
#  ('Tempio', 12),
#  ('Dallapè', 12),
#  ('Mutui', 12),
#  ('Ingegneri', 12),
#  ('Cafe', 12),
#  ('Riciclo', 12),
#  ('Fallimenti', 12),
#  ('Piano', 12),
#  ('Minoranze', 12),
#  ('Stava', 12),
#  ('Silvano', 12),
#  ('Sara', 12),
#  ('Roma', 12),
#  ('Mercati', 11),
#  ('Regioni', 11),
#  ('Rossa', 11),
#  ('Loppio', 11),
#  ('Boschi', 11),
#  ('Minorenni', 11),
#  ('Malè', 11),
#  ('Giudicarie', 11),
#  ('Focolai', 11),
#  ('Famiglie', 11),
#  ('Precari', 11),
#  ('Sostenibilità', 11),
#  ('Parlamento', 11),
#  ('Scasso', 11),
#  ('Marmolada', 11),
#  ('Benzinai', 11),
#  ('Senzatetto', 11),
#  ('Gaudenti', 11),
#  ('Processi', 11),
#  ('Censimento', 11),
#  ('Simbolo', 11),
#  ('Rimborsi', 11),
#  ('Educazione', 11),
#  ('Detenuti', 11),
#  ('Attentati', 11),
#  ('Falsi', 11),
#  ('Salvatore', 11),
#  ('Abbandono', 11),
#  ('Kessler', 11),
#  ('Miss', 11),
#  ('Rise', 11),
#  ('Marketing', 11),
#  ('Renzo', 11),
#  ('Biologico', 11),
#  ('Tassa', 11),
#  ('Soggiorno', 11),
#  ('Pallavolo', 11),
#  ('Dj3', 10),
#  ('M57', 10),
#  ('Hashish', 10),
#  ('Piante', 10),
#  ('Tempo', 10),
#  ('Dimaro', 10),
#  ('Pinzolo', 10),
#  ('19', 10),
#  ('Elicotteri', 10),
#  ('Orari', 10),
#  ('Popolari', 10),
#  ('Riscaldamento', 10),
#  ('Cervi', 10),
#  ('Caduti', 10),
#  ('Lavoratori', 10),
#  ('Writers', 10),
#  ('Affluenza', 10),
#  ('Prezzi', 10),
#  ('Discoteche', 10),
#  ('Cambiamenti', 10),
#  ('Climatici', 10),
#  ('Deputati', 10),
#  ('Voli', 10),
#  ('Lince', 10),
#  ('Pneumatici', 10),
#  ('Gomme', 10),
#  ('Pasquetta', 10),
#  ('Ghiaccio', 10),
#  ('Estero', 10),
#  ('Esplosivi', 10),
#  ('Dighe', 10),
#  ('Credito', 10),
#  ('Presepi', 10),
#  ('Immacolata', 10),
#  ('Feriti', 10),
#  ('Scomparso', 10),
#  ('Amianto', 10),
#  ('Pistola', 10),
#  ('Piromani', 10),
#  ('Berlusconi', 10),
#  ('Canone', 10),
#  ('Idroelettrico', 10),
#  ('Busa', 10),
#  ('Garanzia', 10),
#  ('Sociologia', 10),
#  ('Cantina', 10),
#  ('Ambulanza', 10),
#  ('Deloitte', 10),
#  ('Romano', 10),
#  ('Maestri', 10),
#  ('Sotalazopa', 10),
#  ('Dicembre', 10),
#  ('Grisenti', 10),
#  ('Giovanna', 10),
#  ('Giugni', 10),
#  ('Associazione', 9),
#  ('Novembre', 9),
#  ('Contenimento', 9),
#  ('Private', 9),
#  ('Misure', 9),
#  ('Lockdown', 9),
#  ('Cles', 9),
#  ('Ledro', 9),
#  ('Mortale', 9),
#  ('Terme', 9),
#  ('Dro', 9),
#  ('Nago', 9),
#  ('Torbole', 9),
#  ...]

# %% [markdown]
# # CHORD DIAGRAM

# %%
# Creo una lista boleana 
def filter_df(initial_column, key):
    return key in initial_column

# %%
keywords = ["Furti","Truffa","Droga","Violenza Sessuale" ,"Truffe","Rapine","Incidenti Stradali" ,"Omicidio","Degrado","Morti" ,"Prostituzione" ,"Coronavirus"];
def correlationDataFrame(keywords, df, stringKeywordsColumnName):
    matrix = []
    for index, key in enumerate(keywords):
        row = [0] * len(keywords)
        boolean = df[stringKeywordsColumnName].apply(lambda x: filter_df(x, key))
        filtered_df = df[boolean]
        super_lista = []
        for lista in filtered_df[stringKeywordsColumnName]:
            super_lista.extend(lista)
        for indice, chiave in enumerate(keywords):
            #print('index = {}, conto = {}, chiave = {}'.format(indice, super_lista.count(chiave), chiave))
            row[indice] = super_lista.count(chiave)
        matrix.append(row)

    #for i in range(len(matrix)):
    #    matrix[i][i] = 0
        
    corrdf = pd.DataFrame(matrix, columns=keywords)
    corrdf.insert(loc=0, column='keys', value=keywords)
    return  corrdf
corrDf = correlationDataFrame(keywords, df, 'list_keywords')
corrDf.to_csv("/home/frabatx/Documents/University/Data_journalism/Project_Article/today_parser/site/src/correlationKeyword.csv",index=False)

# %% [markdown]
# # Keywords importanti per il progetto
# * furti
# * droga
# * orso
# * violenza
# * violenza sessuale
# * truffe
# * rapine
# * incidenti stradali
# * omicidio
# * degrado
# * morti
# * prostituzione
# * coronavirus
#
# Quello che si potrebbe fare é una wordcloud fatta bene con queste keywords in modo da avere una prima immagine chiarificatrice.
# La base da cui parto é quella del sole 24 ore https://lab24.ilsole24ore.com/indice-della-criminalita/.

# %%
#Estraggo gli elementi che fanno parte delle argomentazioni che a me interessano
arguments_list = ["Furti","Truffa","Droga","Sessuale" ,"Truffe","Rapine","Stradali" ,"Omicidio","Degrado","Morti" ,"Prostituzione" ,"Coronavirus"];

def keywordsFrequencyTuple(keywords, total_keywords):
    return [(x,y) for x,y in total_keywords if x in keywords]

tupleKey = keywordsFrequencyTuple(arguments_list, total_keywords)
tupleKey
# Out:
# [('Coronavirus', 932),
#  ('Morti', 865),
#  ('Furti', 780),
#  ('Droga', 570),
#  ('Stradali', 269),
#  ('Truffe', 236),
#  ('Omicidio', 190),
#  ('Rapine', 174),
#  ('Degrado', 140),
#  ('Sessuale', 63),
#  ('Prostituzione', 46),
#  ('Truffa', 37)]

# %% [markdown]
# # Istogramma di distribuzione notizie

# %%
def plotInstogram(tupleKeywords):
    figure(num=None, figsize=(10, 9), dpi=80, facecolor='w', edgecolor='k')

    # Choose the height of the bars
    height = [a_tuple[1] for a_tuple in tupleKeywords]

    # Choose the names of the bars
    bars = [a_tuple[0] for a_tuple in tupleKeywords]
    y_pos = np.arange(len(bars))

    # Create bars
    plt.bar(y_pos, height)
    plt.title('Distribuzione notizie')
    # Create names on the x-axis
    plt.xticks(y_pos, bars, rotation=20)

    style = dict(size=10, color='gray')
    for i in range(0, len(height)):
        plt.text(i, height[i] + 10 , height[i] , ha='center', **style)

    # Show graphic
    plt.show()
plotInstogram(tupleKey)

# %% [markdown]
# # ANDAMENTI ANNUALI DELLE KEYWORDS

# %% [markdown]
# ## Anno

# %%
years = ["2011","2012","2013","2014","2015","2016","2017","2018","2019","2020"]
arguments_list =  ["Furti","Truffa","Droga","Sessuale" ,"Truffe","Rapine","Stradali" ,"Omicidio","Degrado","Morti" ,"Prostituzione" ,"Coronavirus"];

# Creazione del dataset da zero
def frequencyKeywordsPerYear(years,total_keywords, keywords, df, stringKeywordsColumn):
   
    columns_year =  ["Furti","Truffa","Droga","Sessuale" ,"Truffe","Rapine","Stradali" ,"Omicidio","Degrado","Morti" ,"Prostituzione" ,"Coronavirus"];
    counter_df_year = pd.DataFrame(columns=columns_year)

    for year in years:
        df_temp = df[(df['year']==int(year))]
        
        temp_l = list(df_temp[stringKeywordsColumn])
        temp_l = [j for i in temp_l for j in i]
        cnt = Counter(temp_l)

        # Creo le tuple 
        key_value_count = cnt.most_common()
        key_value_count.sort(key= lambda x: x[1], reverse=True)
        # Kw totali per l'intero anno
        total_keywords = [(x,y) for x,y in key_value_count]
        # kw importanti per l'intero anno
        important_keywords = [(x,y) for x,y in total_keywords if x in keywords]
        # creazione dizionario ed aggiungo gli elementi che poi andranno a formare la riga del mio dataframe
        dictionary = {}
        dictionary.update({'year': year})
        for tupla in important_keywords:
            dictionary.update({tupla[0]:tupla[1]})
        counter_df_year = counter_df_year.append(dictionary, ignore_index=True)
    counter_df_year.fillna(0, inplace=True)
    return counter_df_year

counter_df_year = frequencyKeywordsPerYear(years, total_keywords, arguments_list, df, 'list_keywords')

counter_df_year.to_csv("/home/frabatx/Documents/University/Data_journalism/Project_Article/today_parser/site/src/trendPerYear1.csv", index=False)
counter_df_year
# Out:
#    Furti  Truffa  Droga  Sessuale  Truffe  Rapine  Stradali  Omicidio  \
# 0      9       0      4         0       3       2         0         3
# 1    122       2     54         0      30      19         1        14
# 2    104       6     51        10      31      22        32        17
# 3     86       8     44        15      18      23        68        10
# 4     91       3     52         5      27      27        60        53
# 5    113       3     61         4      34      20        34        15
# 6     67       0     54         4      22      20        19        19
# 7     88       2    104        11      30      13        12        27
# 8     61       9     95         2      30      16        32        17
# 9     39       4     51        12      11      12        11        15
#
#    Degrado  Morti  Prostituzione  Coronavirus  year
# 0        0      0              0            0  2011
# 1        0      1              7            0  2012
# 2       14     16              7            0  2013
# 3       16    101              4            0  2014
# 4       31    101             11            0  2015
# 5       17     92              1            0  2016
# 6       21     64              3            0  2017
# 7       20    117              5            0  2018
# 8       12    149              5            0  2019
# 9        9    224              3          932  2020

# %% [markdown]
# # Timeline plots
# Il primo plot prende i dati divisi per anno e li divide per tipologia. Serve per capire le tendenze di un determinato argomento in base all'anno.

# %%
def multilineGridPlotPerYear(counter_df_year):
    #plt.style.use('fivethirtyeight')
    plt.style.use('seaborn-darkgrid')
    plt.figure(figsize=(30, 15))
    # create a color palette
    palette = plt.get_cmap('Set1')

    num1= 0
    for column in counter_df_year.drop('year', axis=1):
        num1+=1
        plt.subplot(3,5, num1)

        # multiple line plot
        for lines in counter_df_year.drop('year', axis=1):
           plt.plot('year', str(lines), data=counter_df_year, marker='', color='grey', linewidth=1, alpha=0.4)

        # Now re do the interesting curve, but biger with distinct color
        plt.plot(counter_df_year['year'], counter_df_year[column], marker='', color = 'orange', linewidth=4, alpha=0.7)

        # Add titles
        plt.title(column.upper(), loc='left', fontsize=12, fontweight=0, color='black' )

    plt.xlabel("Time")
    plt.ylabel("Score")
multilineGridPlotPerYear(counter_df_year)

# %%
column = 'Furti'
def plotMultilinePerYear(counter_df_yera, column):
    #plt.style.use('fivethirtyeight')
    plt.style.use('seaborn-darkgrid')
    plt.figure(figsize=(30, 15))
    # create a color palette
    palette = plt.get_cmap('Set1')

    # multiple line plot
    for lines in counter_df_year.drop('year', axis=1):
       plt.plot('year', str(lines), data=counter_df_year, marker='', color='grey', linewidth=1, alpha=0.4)

    # Now re do the interesting curve, but biger with distinct color
    plt.plot(counter_df_year['year'], counter_df_year[column], marker='', color = 'orange', linewidth=4, alpha=0.7)

    # Add titles
    plt.title(column.upper(), loc='left', fontsize=22, fontweight=0, color='black' )
    plt.xticks(fontsize= 20)
    plt.yticks(fontsize= 20)
    plt.xlabel("Time")
    plt.ylabel("Score")
    
plotMultilinePerYear(counter_df_year, column)

# %% [markdown]
# ## Implementing tfidf sui titoli per ogni keywords

# %%
# stopwords.words('italian')

# %% [markdown]
# Il work flow é quanto segue:
# * convertire in lower case
# * rimuovere la punteggiatura
# * rimuovere gli apostrofi
# * rimuovere i cearatteri singoli
# * rimuovere le stopwords
# * rimuovere la punteggiatura dalle keywords
#
# Calcolare il TFIDF:
# * calcolare il tfidf del body
# * calcolare il tfidf dei titoli
# * moltiplicare il body per alpha
# * iterare per ogni tfidf per ogni documento:
#     * se il token é nel body, replace il body value con il valore del titolo

# %% [markdown]
# # Preprocessing

# %%
def lowercase(data):
    return np.char.lower(data)

def titlestring(data):
    return str.title(data)

def removestopwords(data):
    personal_stopwords = "di in il un che qui la fa chiede già ogni però vie per che sono del una due \
    della hanno ha si le con da dei ed nel al dell non all alla stati nella ad dopo anche gli tre era ma\
    anni dal ai delle segno all poco prima ora state giorni corso altri porta oltre scorso dai parte posto\
    l d dell tra 30 dro cinque sembra ancora oggi anni "
    personal_stopwords = personal_stopwords.split(' ')
    
    new_text = ""
    for word in data.split(" "):
        if word not in stopwords.words('italian') and word not in personal_stopwords:
            new_text = new_text + " " + word
    return new_text

def remove_punctuation(data):
    symbols = "!\"#$%&()*+-./:;<=>?@[\]^_`{|}~\n"
    for i in symbols:
        data = np.char.replace(data, i, ' ')
    return data

def remove_apostrophe(data):
    return np.char.replace(data, "'", " ")

def remove_single_character(data):
    new_text = ""
    for w in data.split():
        if(len(w) > 1):
            new_text = new_text + " " + w
    return new_text

def preprocessing(data, stopwordControl = True):
    
    #print(data)
    if(stopwordControl):
        print("5) Lowercase")
        data = data.apply(lambda x : lowercase(str(x)))
        print("4) Stopwords")
        data = data.apply(lambda x : removestopwords(str(x)))
    else:
        print("4) Titlecase")
        data = data.apply(lambda x : titlestring(str(x)))
    #print(data)
    print("3) Punctualization")
    data = data.apply(lambda x : remove_punctuation(str(x)))
    #print(data)
    print("2) Apostrophe")
    data = data.apply(lambda x : remove_apostrophe(str(x)))
    #print(data)
    print("1) Single character")
    data = data.apply(lambda x : remove_single_character(str(x)))
    #print(data)
    print("0) Finish")
    return data

# %%
df = pd.read_csv('trento/total.csv')
#print("Preprocessing title")
#df["title"] = preprocessing(df['title'])
print("Preprocessing body")
df["text"] = preprocessing(df['text'])
# Out:
# Preprocessing body
# 5) Lowercase
# 4) Stopwords
# 3) Punctualization
# 2) Apostrophe
# 1) Single character
# 0) Finish

# %%
print("Preprocessing keywords")
df["list_keywords"] =  preprocessing(df['list_keywords'], False).apply(lambda x: str.split(x))
df["list_keywords"]
# Out:
# Preprocessing keywords
# 4) Titlecase
# 3) Punctualization
# 2) Apostrophe
# 1) Single character
# 0) Finish
# 0                           [Strade, Trasporti, Viabilità]
# 1                              [Alpini, Esercito, Tamponi]
# 2                       [Bollettino, Contagi, Coronavirus]
# 3        [Incidenti, Montagna, Morti, Morti, In, Montagna]
# 4                    [Ferrate, Incidenti, Montagna, Morti]
#                                ...
# 28676                                             [Lavoro]
# 28677                                         [Tecnologie]
# 28678                                          [Religione]
# 28679                                          [Trasporti]
# 28680                                            [Spaccio]
# Name: list_keywords, Length: 28681, dtype: object

# %%
df.to_csv("trento/totalProcessed.csv")
#df = pd.read_csv('trento/dfTextProcessed3.csv',delimiter=',')

# %% [markdown]
# ##### TODO
# il tfidf che segue l'ho preso da questa guida https://towardsdatascience.com/tf-idf-for-document-ranking-from-scratch-in-python-on-real-world-dataset-796d339a4089

# %%
def important_words(lista):
    for key in lista:
        boolean_filter = df['keywords'].str.contains(key)
        df_temp = df[boolean_filter]
        #TFIDF
        vectorizer = TfidfVectorizer()
        vectors = vectorizer.fit_transform(df_temp['text'].values.astype('U'))
        transformed_documents_as_array = vectors.toarray()
        feature_names = vectorizer.get_feature_names()
        dense = vectors.todense()
        denselist = dense.tolist()
        df_filtered = pd.DataFrame(denselist, columns=feature_names)
        # Sorting sulle colonne con valori piú alti
        s = df_filtered.sum(axis =0)
        best_words = df_filtered[s.sort_values(ascending=False).index[:100]].columns.to_list()
        print("Best words for {} keyword: {}".format(key.upper(), best_words))
        return df_filtered

# %% [markdown]
# # TFIDF KEYWORDS STRING

# %%
arguments_list = [ 'furti','droga','orso','violenza','violenza sessuale' ,'truffe','rapine','incidenti stradali' ,'omicidio','degrado','morti' ,'prostituzione']
header = ["key", "value"]
path = "/home/frabatx/Documents/University/Data_journalism/Project_Article/today_parser/site/src/wordcloud/"

def tfidfKeywords(argument_list, df, stringColKey,header, path):
   
    for key in arguments_list:
        boolean_filter = df[stringColKey].str.contains(key)
        df_temp = df[boolean_filter]
        #TFIDF
        vectorizer = TfidfVectorizer()
        vectors = vectorizer.fit_transform(df_temp['text'].values.astype('U'))
        transformed_documents_as_array = vectors.toarray()
        feature_names = vectorizer.get_feature_names()
        dense = vectors.todense()
        denselist = dense.tolist()
        df_filtered = pd.DataFrame(denselist, columns=feature_names)
        # Sorting sulle colonne con valori piú alti
        s = df_filtered.sum(axis =0)
        s.sort_values(ascending=False)[0:100].to_csv(path+'{}.csv'.format(key), header = False)
        
        df_s = pd.read_csv(path+'{}.csv'.format(key),delimiter=',', header=None,)
        df_s.columns = header
        df_s.to_csv(path+'{}.csv'.format(key), index=False)
        

tfidfKeywords(arguments_list, df, 'keywords', header, path)
